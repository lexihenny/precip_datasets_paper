# %%
import numpy as np
import xarray as xr
import scipy.stats as st
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import requests
import os,errno
import sys
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER,LATITUDE_FORMATTER
import matplotlib.ticker as mticker
import cartopy.feature as cfeature
import datetime as dt
import pandas as pd
import time
import urllib.request
import metpy.calc as mpcalc
import salem
import scipy.optimize as opt
import warnings
import geopy.distance
import matplotlib as mpl
import matplotlib.colors as mcolors
from matplotlib.lines import Line2D
import matplotlib.backends.backend_pdf

from scipy.ndimage.measurements import label
from scipy.ndimage import binary_dilation

warnings.filterwarnings('ignore')

# %matplotlib inline

dir_data='/Users/ahenny/'
dir1='/Volumes/LaCie/'
dir2='/Volumes/Extreme Pro/'
dir3='/Volumes/My Passport/day/'

# %%
#ds=xr.open_dataset(dir_data+'precip_datasets_compare_persiann_wet_6070_test.nc')
#ds=xr.open_dataset(dir_data+'precip_datasets_compare_persiann_x_6070_test.nc')
ds=xr.open_dataset(dir_data+'precip_datasets_compare_persiann_r99p_6070_test.nc')
#ds=xr.open_dataset(dir_data+'precip_datasets_compare_persiann_r99p_6070_HQ.nc')

total_list_persiann_ocean=ds['total_list_persiann_ocean'].values.tolist()
freq_list_persiann_ocean=ds['freq_list_persiann_ocean'].values.tolist()
intensity_list_persiann_ocean=ds['intensity_list_persiann_ocean'].values.tolist()

total_list_persiann_land=ds['total_list_persiann_land'].values.tolist()
freq_list_persiann_land=ds['freq_list_persiann_land'].values.tolist()
intensity_list_persiann_land=ds['intensity_list_persiann_land'].values.tolist()

total_persiann_ocean_monthly=ds['total_persiann_ocean_monthly'].values
freq_persiann_ocean_monthly=ds['freq_persiann_ocean_monthly'].values
intensity_persiann_ocean_monthly=ds['intensity_persiann_ocean_monthly'].values

total_persiann_land_monthly=ds['total_persiann_land_monthly'].values
freq_persiann_land_monthly=ds['freq_persiann_land_monthly'].values
intensity_persiann_land_monthly=ds['intensity_persiann_land_monthly'].values

# %%
ds.close()
#ds=xr.open_dataset(dir_data+'precip_datasets_compare_mswep_past_wet_6070_test.nc')
#ds=xr.open_dataset(dir_data+'precip_datasets_compare_mswep_past_x_6070_test.nc')
ds=xr.open_dataset(dir_data+'precip_datasets_compare_mswep_past_r99p_6070_test.nc')
#ds=xr.open_dataset(dir_data+'precip_datasets_compare_mswep_past_r99p_6070_HQ.nc')

total_list_mswep_past_ocean=ds['total_list_mswep_past_ocean'].values.tolist()
freq_list_mswep_past_ocean=ds['freq_list_mswep_past_ocean'].values.tolist()
intensity_list_mswep_past_ocean=ds['intensity_list_mswep_past_ocean'].values.tolist()

total_list_mswep_past_land=ds['total_list_mswep_past_land'].values.tolist()
freq_list_mswep_past_land=ds['freq_list_mswep_past_land'].values.tolist()
intensity_list_mswep_past_land=ds['intensity_list_mswep_past_land'].values.tolist()

total_mswep_past_ocean_monthly=ds['total_mswep_past_ocean_monthly'].values
freq_mswep_past_ocean_monthly=ds['freq_mswep_past_ocean_monthly'].values
intensity_mswep_past_ocean_monthly=ds['intensity_mswep_past_ocean_monthly'].values

total_mswep_past_land_monthly=ds['total_mswep_past_land_monthly'].values
freq_mswep_past_land_monthly=ds['freq_mswep_past_land_monthly'].values
intensity_mswep_past_land_monthly=ds['intensity_mswep_past_land_monthly'].values

# %%
#ds=xr.open_dataset(dir_data+'precip_datasets_compare_imerg_wet_6070_test.nc')
#ds=xr.open_dataset(dir_data+'precip_datasets_compare_imerg_x_6070_test.nc')
ds=xr.open_dataset(dir_data+'precip_datasets_compare_imerg_r99p_6070_test.nc')
#ds=xr.open_dataset(dir_data+'precip_datasets_compare_imerg_r99p_6070_HQ.nc')

total_list_imerg_ocean=ds['total_list_imerg_ocean'].values.tolist()
freq_list_imerg_ocean=ds['freq_list_imerg_ocean'].values.tolist()
intensity_list_imerg_ocean=ds['intensity_list_imerg_ocean'].values.tolist()

total_list_imerg_land=ds['total_list_imerg_land'].values.tolist()
freq_list_imerg_land=ds['freq_list_imerg_land'].values.tolist()
intensity_list_imerg_land=ds['intensity_list_imerg_land'].values.tolist()

total_imerg_ocean_monthly=ds['total_imerg_ocean_monthly'].values
freq_imerg_ocean_monthly=ds['freq_imerg_ocean_monthly'].values
intensity_imerg_ocean_monthly=ds['intensity_imerg_ocean_monthly'].values

total_imerg_land_monthly=ds['total_imerg_land_monthly'].values
freq_imerg_land_monthly=ds['freq_imerg_land_monthly'].values
intensity_imerg_land_monthly=ds['intensity_imerg_land_monthly'].values

# %%
#ds=xr.open_dataset(dir_data+'precip_datasets_compare_cpc_wet_6070_test.nc')
#ds=xr.open_dataset(dir_data+'precip_datasets_compare_cpc_x_6070_test.nc')
ds=xr.open_dataset(dir_data+'precip_datasets_compare_cpc_r99p_6070_test.nc')
#ds=xr.open_dataset(dir_data+'precip_datasets_compare_cpc_r99p_6070_HQ.nc')

total_list_cpc_land=ds['total_list_cpc_land'].values.tolist()
freq_list_cpc_land=ds['freq_list_cpc_land'].values.tolist()
intensity_list_cpc_land=ds['intensity_list_cpc_land'].values.tolist()

total_cpc_land_monthly=ds['total_cpc_land_monthly'].values
freq_cpc_land_monthly=ds['freq_cpc_land_monthly'].values
intensity_cpc_land_monthly=ds['intensity_cpc_land_monthly'].values

# %%
#ds=xr.open_dataset(dir_data+'precip_datasets_compare_gpcp_wet_6070_test.nc')
#ds=xr.open_dataset(dir_data+'precip_datasets_compare_gpcp_x_6070_test.nc')
ds=xr.open_dataset(dir_data+'precip_datasets_compare_gpcp_r99p_6070_test.nc')
#ds=xr.open_dataset(dir_data+'precip_datasets_compare_gpcp_r99p_6070_HQ.nc')

total_list_gpcp_ocean=ds['total_list_gpcp_ocean'].values.tolist()
freq_list_gpcp_ocean=ds['freq_list_gpcp_ocean'].values.tolist()
intensity_list_gpcp_ocean=ds['intensity_list_gpcp_ocean'].values.tolist()

total_list_gpcp_land=ds['total_list_gpcp_land'].values.tolist()
freq_list_gpcp_land=ds['freq_list_gpcp_land'].values.tolist()
intensity_list_gpcp_land=ds['intensity_list_gpcp_land'].values.tolist()

total_gpcp_ocean_monthly=ds['total_gpcp_ocean_monthly'].values
freq_gpcp_ocean_monthly=ds['freq_gpcp_ocean_monthly'].values
intensity_gpcp_ocean_monthly=ds['intensity_gpcp_ocean_monthly'].values

total_gpcp_land_monthly=ds['total_gpcp_land_monthly'].values
freq_gpcp_land_monthly=ds['freq_gpcp_land_monthly'].values
intensity_gpcp_land_monthly=ds['intensity_gpcp_land_monthly'].values

# %%
#ds=xr.open_dataset(dir_data+'precip_datasets_compare_gpcp3_wet_6070_test.nc')
#ds=xr.open_dataset(dir_data+'precip_datasets_compare_gpcp3_x_6070_test.nc')
ds=xr.open_dataset(dir_data+'precip_datasets_compare_gpcp3_r99p_6070_test.nc')
#ds=xr.open_dataset(dir_data+'precip_datasets_compare_gpcp3_r99p_6070_HQ.nc')

total_list_gpcp3_ocean=ds['total_list_gpcp3_ocean'].values.tolist()
freq_list_gpcp3_ocean=ds['freq_list_gpcp3_ocean'].values.tolist()
intensity_list_gpcp3_ocean=ds['intensity_list_gpcp3_ocean'].values.tolist()

total_list_gpcp3_land=ds['total_list_gpcp3_land'].values.tolist()
freq_list_gpcp3_land=ds['freq_list_gpcp3_land'].values.tolist()
intensity_list_gpcp3_land=ds['intensity_list_gpcp3_land'].values.tolist()

total_gpcp3_ocean_monthly=ds['total_gpcp3_ocean_monthly'].values
freq_gpcp3_ocean_monthly=ds['freq_gpcp3_ocean_monthly'].values
intensity_gpcp3_ocean_monthly=ds['intensity_gpcp3_ocean_monthly'].values

total_gpcp3_land_monthly=ds['total_gpcp3_land_monthly'].values
freq_gpcp3_land_monthly=ds['freq_gpcp3_land_monthly'].values
intensity_gpcp3_land_monthly=ds['intensity_gpcp3_land_monthly'].values

# %%
ds.close()
#ds=xr.open_dataset(dir_data+'precip_datasets_compare_regenfull_wet_6070_test.nc')
#ds=xr.open_dataset(dir_data+'precip_datasets_compare_regenfull_x_6070_test.nc')
ds=xr.open_dataset(dir_data+'precip_datasets_compare_regenfull_r99p_6070_test.nc')
#ds=xr.open_dataset(dir_data+'precip_datasets_compare_regen_r99p_6070_test.nc')

total_list_regen_land=ds['total_list_regen_land'].values.tolist()
freq_list_regen_land=ds['freq_list_regen_land'].values.tolist()
intensity_list_regen_land=ds['intensity_list_regen_land'].values.tolist()

total_regen_land_monthly=ds['total_regen_land_monthly'].values
freq_regen_land_monthly=ds['freq_regen_land_monthly'].values
intensity_regen_land_monthly=ds['intensity_regen_land_monthly'].values

# %%
#ds=xr.open_dataset(dir_data+'precip_datasets_compare_gpcc_wet_6070_test.nc')
#ds=xr.open_dataset(dir_data+'precip_datasets_compare_gpcc_x_6070_test.nc')
ds=xr.open_dataset(dir_data+'precip_datasets_compare_gpcc_r99p_6070_test.nc')
#ds=xr.open_dataset(dir_data+'precip_datasets_compare_gpcc_r99p_6070_HQ.nc')

total_list_gpcc_land=ds['total_list_gpcc_land'].values.tolist()
freq_list_gpcc_land=ds['freq_list_gpcc_land'].values.tolist()
intensity_list_gpcc_land=ds['intensity_list_gpcc_land'].values.tolist()

total_gpcc_land_monthly=ds['total_gpcc_land_monthly'].values
freq_gpcc_land_monthly=ds['freq_gpcc_land_monthly'].values
intensity_gpcc_land_monthly=ds['intensity_gpcc_land_monthly'].values

# %%
ds.close()
ds=xr.open_dataset(dir_data+'hadex3_lines_r99p.nc')
#ds=xr.open_dataset(dir_data+'hadex3_lines_r95p_HQ.nc')
#ds=xr.open_dataset(dir_data+'hadex3_lines_total.nc')
starting_01=ds['starting_01'].values.tolist()
starting_40=ds['starting_40'].values.tolist()
starting_50=ds['starting_50'].values.tolist()
starting_79=ds['starting_79'].values.tolist()
#starting_80=ds['starting_80'].values.tolist()

# %%
#ds=xr.open_dataset(dir_data+'precip_datasets_compare_jra55_wet_6070_test.nc')
#ds=xr.open_dataset(dir_data+'precip_datasets_compare_jra55_x_6070_test.nc')
ds=xr.open_dataset(dir_data+'precip_datasets_compare_jra55_r99p_6070_test.nc')
#ds=xr.open_dataset(dir_data+'precip_datasets_compare_jra55_r99p_6070_HQ.nc')

total_list_jra55_ocean=ds['total_list_jra55_ocean'].values.tolist()
freq_list_jra55_ocean=ds['freq_list_jra55_ocean'].values.tolist()
intensity_list_jra55_ocean=ds['intensity_list_jra55_ocean'].values.tolist()

total_list_jra55_land=ds['total_list_jra55_land'].values.tolist()
freq_list_jra55_land=ds['freq_list_jra55_land'].values.tolist()
intensity_list_jra55_land=ds['intensity_list_jra55_land'].values.tolist()

total_jra55_ocean_monthly=ds['total_jra55_ocean_monthly'].values
freq_jra55_ocean_monthly=ds['freq_jra55_ocean_monthly'].values
intensity_jra55_ocean_monthly=ds['intensity_jra55_ocean_monthly'].values

total_jra55_land_monthly=ds['total_jra55_land_monthly'].values
freq_jra55_land_monthly=ds['freq_jra55_land_monthly'].values
intensity_jra55_land_monthly=ds['intensity_jra55_land_monthly'].values

# %%
#ds=xr.open_dataset(dir_data+'precip_datasets_compare_era5_wet_6070_test.nc')
#ds=xr.open_dataset(dir_data+'precip_datasets_compare_era5_x_6070_test.nc')
ds=xr.open_dataset(dir_data+'precip_datasets_compare_era5_r99p_6070_test.nc')
#ds=xr.open_dataset(dir_data+'precip_datasets_compare_era5_r99p_6070_HQ.nc')

total_list_era5_ocean=ds['total_list_era5_ocean'].values.tolist()
freq_list_era5_ocean=ds['freq_list_era5_ocean'].values.tolist()
intensity_list_era5_ocean=ds['intensity_list_era5_ocean'].values.tolist()

total_list_era5_land=ds['total_list_era5_land'].values.tolist()
freq_list_era5_land=ds['freq_list_era5_land'].values.tolist()
intensity_list_era5_land=ds['intensity_list_era5_land'].values.tolist()

total_era5_ocean_monthly=ds['total_era5_ocean_monthly'].values
freq_era5_ocean_monthly=ds['freq_era5_ocean_monthly'].values
intensity_era5_ocean_monthly=ds['intensity_era5_ocean_monthly'].values

total_era5_land_monthly=ds['total_era5_land_monthly'].values
freq_era5_land_monthly=ds['freq_era5_land_monthly'].values
intensity_era5_land_monthly=ds['intensity_era5_land_monthly'].values

# %%
#ds=xr.open_dataset(dir_data+'precip_datasets_compare_merra2_wet_6070_test.nc')
#ds=xr.open_dataset(dir_data+'precip_datasets_compare_merra2_x_6070_test.nc')
ds=xr.open_dataset(dir_data+'precip_datasets_compare_merra2_r99p_6070_test.nc')
#ds=xr.open_dataset(dir_data+'precip_datasets_compare_merra2_r99p_6070_HQ.nc')

total_list_merra2_ocean=ds['total_list_merra2_ocean'].values.tolist()
freq_list_merra2_ocean=ds['freq_list_merra2_ocean'].values.tolist()
intensity_list_merra2_ocean=ds['intensity_list_merra2_ocean'].values.tolist()

total_list_merra2_land=ds['total_list_merra2_land'].values.tolist()
freq_list_merra2_land=ds['freq_list_merra2_land'].values.tolist()
intensity_list_merra2_land=ds['intensity_list_merra2_land'].values.tolist()

total_merra2_ocean_monthly=ds['total_merra2_ocean_monthly'].values
freq_merra2_ocean_monthly=ds['freq_merra2_ocean_monthly'].values
intensity_merra2_ocean_monthly=ds['intensity_merra2_ocean_monthly'].values

total_merra2_land_monthly=ds['total_merra2_land_monthly'].values
freq_merra2_land_monthly=ds['freq_merra2_land_monthly'].values
intensity_merra2_land_monthly=ds['intensity_merra2_land_monthly'].values

# %%
month_days=[31,28.25,31,30,31,30,31,31,30,31,30,31]


yrs=np.arange(1983,2023,1)
for i in range(len(yrs)):
    if i==0:
        total_month_persiann_land=list(total_persiann_land_monthly[:,i])
    else:
        total_month_persiann_land=total_month_persiann_land+list(total_persiann_land_monthly[:,i])
        
yrs=np.arange(1979,2023,1)
for i in range(len(yrs)):
    if i==0:
        total_month_cpc_land=list(total_cpc_land_monthly[:,i])
    else:
        total_month_cpc_land=total_month_cpc_land+list(total_cpc_land_monthly[:,i])

yrs=np.arange(1979,2021,1)
for i in range(len(yrs)):
    if i==0:
        total_month_mswep_past_land=list(total_mswep_past_land_monthly[:,i])
    else:
        total_month_mswep_past_land=total_month_mswep_past_land+list(total_mswep_past_land_monthly[:,i])

yrs=np.arange(2001,2023,1)
for i in range(len(yrs)):
    if i==0:
        total_month_imerg_land=list(total_imerg_land_monthly[:,i])
    else:
        total_month_imerg_land=total_month_imerg_land+list(total_imerg_land_monthly[:,i])

yrs=np.arange(1997,2023,1)
for i in range(len(yrs)):
    if i==0:
        total_month_gpcp_land=list(total_gpcp_land_monthly[:,i])
    else:
        total_month_gpcp_land=total_month_gpcp_land+list(total_gpcp_land_monthly[:,i])
        
yrs=np.arange(2001,2021,1)
for i in range(len(yrs)):
    if i==0:
        total_month_gpcp3_land=list(total_gpcp3_land_monthly[:,i])
    else:
        total_month_gpcp3_land=total_month_gpcp3_land+list(total_gpcp3_land_monthly[:,i])
        
yrs=np.arange(1950,2017,1)
for i in range(len(yrs)):
    if i==0:
        total_month_regen_land=list(total_regen_land_monthly[:,i])
    else:
        total_month_regen_land=total_month_regen_land+list(total_regen_land_monthly[:,i])
        
yrs=np.arange(1982,2021,1)
for i in range(len(yrs)):
    if i==0:
        total_month_gpcc_land=list(total_gpcc_land_monthly[:,i])
    else:
        total_month_gpcc_land=total_month_gpcc_land+list(total_gpcc_land_monthly[:,i])
        
yrs=np.arange(1980,2023,1)
for i in range(len(yrs)):
    if i==0:
        total_month_merra2_land=list(total_merra2_land_monthly[:,i])
    else:
        total_month_merra2_land=total_month_merra2_land+list(total_merra2_land_monthly[:,i])
        
yrs=np.arange(1958,2023,1)
for i in range(len(yrs)):
    if i==0:
        total_month_jra55_land=list(total_jra55_land_monthly[:,i])
    else:
        total_month_jra55_land=total_month_jra55_land+list(total_jra55_land_monthly[:,i])
        
yrs=np.arange(1940,2023,1)
for i in range(len(yrs)):
    if i==0:
        total_month_era5_land=list(total_era5_land_monthly[:,i])
    else:
        total_month_era5_land=total_month_era5_land+list(total_era5_land_monthly[:,i])

test=[x/12. for x in total_list_mswep_past_land]

yrs=np.arange(1979,2021,1)
zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0]
select_values=[x[1] for x in zipped_years if x[1]>=0]
r=st.linregress(select_years,select_values)

change=r[0]*len(yrs)
mean=float(sum(select_values))/float(len(select_values))
if r[3]<=0.0351:
    label_5='MSWEP V2.8 (Mean='+str(round(mean,1))+', '+'$\Delta$='+r'$\bf{'+str(round(change,2))+'}$'+', p='+str(round(r[3],3))+')'
else:
    label_5='MSWEP V2.8 (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

if 1==1:
    test=[x/12. for x in total_list_persiann_land]
    
    yrs=np.arange(1983,2023,1)
    zipped_years=list(zip(yrs,test))
    select_years=[x[0] for x in zipped_years if x[1]>=0]
    select_values=[x[1] for x in zipped_years if x[1]>=0]
    r=st.linregress(select_years,select_values)

    change=r[0]*len(yrs)
    mean=float(sum(select_values))/float(len(select_values))
    if r[3]<=0.0351:
        label_6='PERSIANN-CDR (Mean='+str(round(mean,1))+', '+'$\Delta$='+r'$\bf{'+str(round(change,2))+'}$'+', p='+str(round(r[3],3))+')'
    else:
        label_6='PERSIANN-CDR (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'
    
    yrs=np.arange(1979,2024,1)
    test=[x/12. for x in total_list_cpc_land]
    r=st.linregress(yrs[1:-1],test[1:-1])
    change=r[0]*len(yrs[1:-1])
    mean=float(sum(test[1:-1]))/float(len(test[1:-1]))
    if r[3]<=0.0351:
        label_7='CPC Unified (Mean='+str(round(mean,1))+', '+'$\Delta$='+r'$\bf{'+str(round(change,2))+'}$'+', p='+str(round(r[3],3))+')'
    else:
        label_7='CPC Unified (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

    yrs=np.arange(2001,2023,1)
    test=[x/12. for x in total_list_imerg_land]
    r=st.linregress(yrs,test)
    change=r[0]*len(yrs)
    mean=float(sum(test))/float(len(test))
    if r[3]<=0.0351:
        label_8='IMERG V07a (Mean='+str(round(mean,1))+', '+'$\Delta$='+r'$\bf{'+str(round(change,2))+'}$'+', p='+str(round(r[3],3))+')'
    else:
        label_8='IMERG V07a (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

    yrs=np.arange(1997,2023,1)
    test=[x/12. for x in total_list_gpcp_land]
    r=st.linregress(yrs,test)
    change=r[0]*len(yrs)
    mean=float(sum(test))/float(len(test))
    if r[3]<=0.0351:
        label_9='GPCP Daily CDR (Mean='+str(round(mean,1))+', '+'$\Delta$='+r'$\bf{'+str(round(change,2))+'}$'+', p='+str(round(r[3],3))+')'
    else:
        label_9='GPCP Daily CDR (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

    yrs=np.arange(1950,2017,1)
    test=[x/12. for x in total_list_regen_land]
    r=st.linregress(yrs[30:],test[30:])
    change=r[0]*len(yrs[30:])
    mean=float(sum(test[30:]))/float(len(test[30:]))
    if r[3]<=0.0351:
        label_10='REGEN (Mean='+str(round(mean,1))+', '+'$\Delta$='+r'$\bf{'+str(round(change,2))+'}$'+', p='+str(round(r[3],3))+')'
    else:
        label_10='REGEN (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

    yrs=np.arange(1982,2021,1)
    test=[x/12. for x in total_list_gpcc_land]
    r=st.linregress(yrs,test)
    change=r[0]*len(yrs)
    mean=float(sum(test))/float(len(test))
    if r[3]<=0.0351:
        label_11='GPCC V2022 (Mean='+str(round(mean,1))+', '+'$\Delta$='+r'$\bf{'+str(round(change,2))+'}$'+', p='+str(round(r[3],3))+')'
    else:
        label_11='GPCC V2022 (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

    yrs=np.arange(1940,2019,1)
    test=[x/12. for x in starting_40]
    r=st.linregress(yrs[40:],test[40:])
    change=r[0]*len(yrs[40:])
    mean=float(sum(test[40:]))/float(len(test[40:]))
    if r[3]<=0.0351:
        label_14='HadEX3 90% 1940 (Mean='+str(round(mean,1))+', '+'$\Delta$='+r'$\bf{'+str(round(change,2))+'}$'+', p='+str(round(r[3],3))+')'
    else:
        label_14='HadEX3 90% 1940 (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

    yrs=np.arange(2001,2021,1)
    test=[x/12. for x in total_list_gpcp3_land]
    r=st.linregress(yrs,test)
    change=r[0]*len(yrs)
    mean=float(sum(test))/float(len(test))
    if r[3]<=0.0351:
        label_15='GPCP V3.2 (Mean='+str(round(mean,1))+', '+'$\Delta$='+r'$\bf{'+str(round(change,2))+'}$'+', p='+str(round(r[3],3))+')'
    else:
        label_15='GPCP V3.2 (Mean='+str(round(mean,1))+', '+str(round(change,2))+', p='+str(round(r[3],3))+')'

    
    yrs=np.arange(1980,2023,1)
    test=[x/12. for x in total_list_merra2_land]
    r=st.linregress(yrs,test)
    change=r[0]*len(yrs)
    mean=float(sum(test))/float(len(test))
    if r[3]<=0.0351:
        label_16='MERRA-2 (Mean='+str(round(mean,1))+', '+'$\Delta$='+r'$\bf{'+str(round(change,2))+'}$'+', p='+str(round(r[3],3))+')'
    else:
        label_16='MERRA-2 (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

    yrs=np.arange(1958,2023,1)
    test=[x/12. for x in total_list_jra55_land]
    r=st.linregress(yrs[22:],test[22:])
    change=r[0]*len(yrs[22:])
    mean=float(sum(test[22:]))/float(len(test[22:]))
    if r[3]<=0.0351:
        label_17='JRA-55 (Mean='+str(round(mean,1))+', '+'$\Delta$='+r'$\bf{'+str(round(change,2))+'}$'+', p='+str(round(r[3],3))+')'
    else:
        label_17='JRA-55 (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

    yrs=np.arange(1940,2023,1)
    test=[x/12. for x in total_list_era5_land]
    r=st.linregress(yrs[40:],test[40:])
    change=r[0]*len(yrs[40:])
    mean=float(sum(test[40:]))/float(len(test[40:]))
    if r[3]<=0.0351:
        label_18='ERA5 (Mean='+str(round(mean,1))+', '+'$\Delta$='+r'$\bf{'+str(round(change,2))+'}$'+', p='+str(round(r[3],3))+')'
    else:
        label_18='ERA5 (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

    
from matplotlib.colors import LinearSegmentedColormap
#cmap1=LinearSegmentedColormap.from_list('new_cmap',['k','grey','b','dodgerblue','mediumorchid','darkviolet'])
#cmap1=LinearSegmentedColormap.from_list('new_cmap',['k','darkgrey','b','dodgerblue','darkviolet','indigo'])
#cmap1=LinearSegmentedColormap.from_list('new_cmap',['k','b','dodgerblue','darkslategray','darkviolet','indigo'])
#cmap1=LinearSegmentedColormap.from_list('new_cmap',['k','darkblue','b','teal','darkviolet','indigo'])
cmap1=LinearSegmentedColormap.from_list('new_cmap',['k','darkblue','b','darkslategray','lightseagreen','indigo'])
#darkslategray
colors1=cmap1(np.linspace(0,1,6))

cmap2=LinearSegmentedColormap.from_list('new_cmap',['magenta','red','orange','yellow'])
#cmap2=LinearSegmentedColormap.from_list('new_cmap',['magenta','red','yellow','orange'])
colors2=cmap2(np.linspace(0,1,5))
#colors2=cmap2(np.linspace(0,1,3))
#fig=plt.figure(figsize=(16,12))
fig=plt.figure(figsize=(12,18))
ax=plt.subplot(1,1,1)

width=0.75
if 1==1:
   
    x_arr=np.arange(1949.5,2016.5,1./12.)
    ax.plot(x_arr,total_month_regen_land,color='b',linewidth=width,alpha=0.55)
    x_arr=np.arange(1978.5,2022.5,1./12.)
    ax.plot(x_arr,total_month_cpc_land,color='darkturquoise',linewidth=1.1,alpha=0.55)
    x_arr=np.arange(1981.5,2020.5,1./12.)
    ax.plot(x_arr,total_month_gpcc_land,color='blueviolet',linewidth=width,alpha=0.55)

width=0.75
alpha=0.55
if 1==1:
    x_arr=np.arange(1939.5,2022.5,1./12.)
    ax.plot(x_arr,total_month_era5_land,color='darkblue',linewidth=width,alpha=alpha)
    x_arr=np.arange(1957.5,2022.5,1./12.)
    ax.plot(x_arr,total_month_jra55_land,color='dodgerblue',linewidth=width,alpha=alpha)
    x_arr=np.arange(1979.5,2022.5,1./12.)
    ax.plot(x_arr,total_month_merra2_land,color='w',linewidth=width,alpha=alpha)
    x_arr=np.arange(1978.5,2020.5,1./12.)
    ax.plot(x_arr,total_month_mswep_past_land,color=colors2[0],linewidth=width,alpha=alpha)#1
    x_arr=np.arange(1996.5,2022.5,1./12.)
    ax.plot(x_arr,total_month_gpcp_land,color=colors2[1],linewidth=width,alpha=alpha)
    x_arr=np.arange(2000.5,2020.5,1./12.)
    ax.plot(x_arr,total_month_gpcp3_land,color=colors2[2],linewidth=width,alpha=alpha)
    x_arr=np.arange(1982.5,2022.5,1./12.)
    ax.plot(x_arr,total_month_persiann_land,color=colors2[4],linewidth=width,alpha=alpha)
    x_arr=np.arange(2000.5,2022.5,1./12.)
    ax.plot(x_arr,total_month_imerg_land,color=colors2[3],linewidth=width,alpha=alpha)

width=6
alpha=1
#ax.plot(np.arange(1940,2019,1),[x/12. for x in starting_40],color='k',linewidth=width,label=label_14)
ax.plot(np.arange(1940,2023,1),[x/12. for x in total_list_era5_land],color='darkblue',linewidth=width,label=label_18,alpha=alpha)
ax.plot(np.arange(1950,2017,1),[x/12. for x in total_list_regen_land],color='b',linewidth=width,label=label_10,zorder=200)
ax.plot(np.arange(1958,2023,1),[x/12. for x in total_list_jra55_land],color='dodgerblue',linewidth=width,label=label_17,alpha=0.75,zorder=204)
ax.plot(np.arange(1979,2024,1),[x/12. for x in total_list_cpc_land],color='darkturquoise',linewidth=width,label=label_7,zorder=201)
ax.plot(np.arange(1982,2021,1),[x/12. for x in total_list_gpcc_land],color='blueviolet',linewidth=width,label=label_11)
ax.plot(np.arange(1980,2023,1),[x/12. for x in total_list_merra2_land],color='w',linewidth=width,label=label_16,alpha=alpha)


ax.fill_between(np.arange(1900,2025,1),3,37,color='gray',alpha=0.8)#R95p
#ax.fill_between(np.arange(1900,2025,1),0.8,13.5,color='gray',alpha=0.8)#R99p

if 1==1:
    ax.plot(np.arange(1979,2021,1),[x/12. for x in total_list_mswep_past_land],color=colors2[0],linewidth=width,label=label_5,alpha=alpha)
    ax.plot(np.arange(1997,2023,1),[x/12. for x in total_list_gpcp_land],color=colors2[1],linewidth=width,label=label_9,alpha=alpha,zorder=202)
    ax.plot(np.arange(2001,2021,1),[x/12. for x in total_list_gpcp3_land],color=colors2[2],linewidth=width,label=label_15,alpha=alpha)
    ax.plot(np.arange(2001,2023,1),[x/12. for x in total_list_imerg_land],color=colors2[3],linewidth=width,label=label_8,alpha=alpha)
    ax.plot(np.arange(1983,2023,1),[x/12. for x in total_list_persiann_land],color=colors2[4],linewidth=width,label=label_6,alpha=alpha)

    ax.plot(1983,total_list_persiann_land[0]/12.,marker='o',color='yellow',markersize=10)
    ax.plot(1985,total_list_persiann_land[2]/12.,marker='o',color='yellow',markersize=10)



#ax.plot(np.arange(1940,2023,1),[x+2 for x in test],color='limegreen',linestyle='solid',linewidth=4,alpha=0.85,zorder=10)

#plt.axvline(x=1990,linewidth=3,linestyle='--',color='k')
#plt.axvline(x=2021,linewidth=3,linestyle='--',color='k')

ax.tick_params(labelsize=20)
ax.set_xlabel('Year',fontsize=22)
ax.set_ylabel('mm month$^{-1}$',fontsize=22)
#ax.set_title(r'$\bf{Wet}$'+' '+r'$\bf{day}$'+' '+r'$\bf{total}$',fontsize=34,pad=5)
#ax.set_title(r'$\bf{EP}$'+' '+r'$\bf{total}$',fontsize=34,pad=5)
#ax.set_title(r'$\bf{R99p}$',fontsize=34,pad=5)
ax.set_title(r'$\bf{R99p-}$'+' '+r'$\bf{land}$',fontsize=31,pad=5)
ax.set_title(r'$\bf{R98p_{all}-}$'+' '+r'$\bf{land}$',fontsize=31,pad=5)
ax.grid(True,linewidth=2)
plt.legend(loc='upper left',fontsize=14.4,ncol=1)#16.4
#ax.set_xlim(1978.8,2022.2)
ax.set_xlim(1939.3,2023.6)
#ax.set_ylim(7,34.2)#R95p
#ax.set_ylim(0.8,13.5)#R99p
ax.set_ylim(5.1,32.3)#R95p
for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(1.75)

#ax.fill_between(np.arange(2021,2024,1),200,1150,color='gray',alpha=0.3)
plt.show()

# %%
fig.savefig(dir_data+'big_precip_consensus_new_1b.png',dpi=300)

# %%
month_days=[31,28.25,31,30,31,30,31,31,30,31,30,31]


yrs=np.arange(1983,2023,1)
for i in range(len(yrs)):
    if i==0:
        total_month_persiann_ocean=list(freq_persiann_ocean_monthly[:,i])
    else:
        total_month_persiann_ocean=total_month_persiann_ocean+list(freq_persiann_ocean_monthly[:,i])
        
yrs=np.arange(1979,2021,1)
for i in range(len(yrs)):
    if i==0:
        total_month_mswep_past_ocean=list(freq_mswep_past_ocean_monthly[:,i])
    else:
        total_month_mswep_past_ocean=total_month_mswep_past_ocean+list(freq_mswep_past_ocean_monthly[:,i])

yrs=np.arange(2001,2023,1)
for i in range(len(yrs)):
    if i==0:
        total_month_imerg_ocean=list(freq_imerg_ocean_monthly[:,i])
    else:
        total_month_imerg_ocean=total_month_imerg_ocean+list(freq_imerg_ocean_monthly[:,i])

yrs=np.arange(1997,2023,1)
for i in range(len(yrs)):
    if i==0:
        total_month_gpcp_ocean=list(freq_gpcp_ocean_monthly[:,i])
    else:
        total_month_gpcp_ocean=total_month_gpcp_ocean+list(freq_gpcp_ocean_monthly[:,i])
        
yrs=np.arange(2001,2021,1)
for i in range(len(yrs)):
    if i==0:
        total_month_gpcp3_ocean=list(freq_gpcp3_ocean_monthly[:,i])
    else:
        total_month_gpcp3_ocean=total_month_gpcp3_ocean+list(freq_gpcp3_ocean_monthly[:,i])
         
yrs=np.arange(1980,2023,1)
for i in range(len(yrs)):
    if i==0:
        total_month_merra2_ocean=list(freq_merra2_ocean_monthly[:,i])
    else:
        total_month_merra2_ocean=total_month_merra2_ocean+list(freq_merra2_ocean_monthly[:,i])
        
yrs=np.arange(1958,2023,1)
for i in range(len(yrs)):
    if i==0:
        total_month_jra55_ocean=list(freq_jra55_ocean_monthly[:,i])
    else:
        total_month_jra55_ocean=total_month_jra55_ocean+list(freq_jra55_ocean_monthly[:,i])
        
yrs=np.arange(1940,2023,1)
for i in range(len(yrs)):
    if i==0:
        total_month_era5_ocean=list(freq_era5_ocean_monthly[:,i])
    else:
        total_month_era5_ocean=total_month_era5_ocean+list(freq_era5_ocean_monthly[:,i])

test=[x/12. for x in freq_list_mswep_past_ocean]

yrs=np.arange(1979,2021,1)
zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0]
select_values=[x[1] for x in zipped_years if x[1]>=0]
r=st.linregress(select_years,select_values)

change=r[0]*len(yrs)
mean=float(sum(select_values))/float(len(select_values))
if r[3]<=0.0351:
    label_5='MSWEP V2.8 (Mean='+str(round(mean,1))+', '+'$\Delta$='+r'$\bf{'+str(round(change,2))+'}$'+', p='+str(round(r[3],3))+')'
else:
    label_5='MSWEP V2.8 (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

if 1==1:
    test=[x/12. for x in freq_list_persiann_ocean]
    
    yrs=np.arange(1983,2023,1)
    zipped_years=list(zip(yrs,test))
    select_years=[x[0] for x in zipped_years if x[1]>=0]
    select_values=[x[1] for x in zipped_years if x[1]>=0]
    r=st.linregress(select_years,select_values)

    change=r[0]*len(yrs)
    mean=float(sum(select_values))/float(len(select_values))
    if r[3]<=0.0351:
        label_6='PERSIANN-CDR (Mean='+str(round(mean,1))+', '+'$\Delta$='+r'$\bf{'+str(round(change,2))+'}$'+', p='+str(round(r[3],3))+')'
    else:
        label_6='PERSIANN-CDR (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'
    
    yrs=np.arange(2001,2023,1)
    test=[x/12. for x in freq_list_imerg_ocean]
    r=st.linregress(yrs,test)
    change=r[0]*len(yrs)
    mean=float(sum(test))/float(len(test))
    if r[3]<=0.0351:
        label_8='IMERG V07a (Mean='+str(round(mean,1))+', '+'$\Delta$='+r'$\bf{'+str(round(change,2))+'}$'+', p='+str(round(r[3],3))+')'
    else:
        label_8='IMERG V07a (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

    yrs=np.arange(1997,2023,1)
    test=[x/12. for x in freq_list_gpcp_ocean]
    r=st.linregress(yrs,test)
    change=r[0]*len(yrs)
    mean=float(sum(test))/float(len(test))
    if r[3]<=0.0351:
        label_9='GPCP Daily CDR (Mean='+str(round(mean,1))+', '+'$\Delta$='+r'$\bf{'+str(round(change,2))+'}$'+', p='+str(round(r[3],3))+')'
    else:
        label_9='GPCP Daily CDR (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

    yrs=np.arange(2001,2021,1)
    test=[x/12. for x in freq_list_gpcp3_ocean]
    r=st.linregress(yrs,test)
    change=r[0]*len(yrs)
    mean=float(sum(test))/float(len(test))
    if r[3]<=0.0351:
        label_15='GPCP V3.2 (Mean='+str(round(mean,1))+', '+'$\Delta$='+r'$\bf{'+str(round(change,2))+'}$'+', p='+str(round(r[3],3))+')'
    else:
        label_15='GPCP V3.2 (Mean='+str(round(mean,1))+', '+str(round(change,2))+', p='+str(round(r[3],3))+')'

    
    yrs=np.arange(1980,2023,1)
    test=[x/12. for x in freq_list_merra2_ocean]
    r=st.linregress(yrs,test)
    change=r[0]*len(yrs)
    mean=float(sum(test))/float(len(test))
    if r[3]<=0.0351:
        label_16='MERRA-2 (Mean='+str(round(mean,1))+', '+'$\Delta$='+r'$\bf{'+str(round(change,2))+'}$'+', p='+str(round(r[3],3))+')'
    else:
        label_16='MERRA-2 (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

    yrs=np.arange(1958,2023,1)
    test=[x/12. for x in freq_list_jra55_ocean]
    r=st.linregress(yrs[22:],test[22:])
    change=r[0]*len(yrs[22:])
    mean=float(sum(test[22:]))/float(len(test[22:]))
    if r[3]<=0.0351:
        label_17='JRA-55 (Mean='+str(round(mean,1))+', '+'$\Delta$='+r'$\bf{'+str(round(change,2))+'}$'+', p='+str(round(r[3],3))+')'
    else:
        label_17='JRA-55 (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

    yrs=np.arange(1940,2023,1)
    test=[x/12. for x in freq_list_era5_ocean]
    r=st.linregress(yrs[40:],test[40:])
    change=r[0]*len(yrs[40:])
    mean=float(sum(test[40:]))/float(len(test[40:]))
    if r[3]<=0.0351:
        label_18='ERA5 (Mean='+str(round(mean,1))+', '+'$\Delta$='+r'$\bf{'+str(round(change,2))+'}$'+', p='+str(round(r[3],3))+')'
    else:
        label_18='ERA5 (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

    
from matplotlib.colors import LinearSegmentedColormap
#cmap1=LinearSegmentedColormap.from_list('new_cmap',['k','grey','b','dodgerblue','mediumorchid','darkviolet'])
#cmap1=LinearSegmentedColormap.from_list('new_cmap',['k','darkgrey','b','dodgerblue','darkviolet','indigo'])
#cmap1=LinearSegmentedColormap.from_list('new_cmap',['k','b','dodgerblue','darkslategray','darkviolet','indigo'])
#cmap1=LinearSegmentedColormap.from_list('new_cmap',['k','darkblue','b','teal','darkviolet','indigo'])
cmap1=LinearSegmentedColormap.from_list('new_cmap',['k','darkblue','b','darkslategray','lightseagreen','indigo'])
#darkslategray
colors1=cmap1(np.linspace(0,1,6))

cmap2=LinearSegmentedColormap.from_list('new_cmap',['magenta','red','orange','yellow'])
#cmap2=LinearSegmentedColormap.from_list('new_cmap',['magenta','red','yellow','orange'])
colors2=cmap2(np.linspace(0,1,5))
#colors2=cmap2(np.linspace(0,1,3))
#fig=plt.figure(figsize=(16,12))
fig=plt.figure(figsize=(12,18))
ax=plt.subplot(1,1,1)

width=0.75
alpha=0.55
if 1==1:
    x_arr=np.arange(1939.5,2022.5,1./12.)
    ax.plot(x_arr,total_month_era5_ocean,color='darkblue',linewidth=width,alpha=alpha)
    x_arr=np.arange(1957.5,2022.5,1./12.)
    ax.plot(x_arr,total_month_jra55_ocean,color='dodgerblue',linewidth=width,alpha=alpha)
    x_arr=np.arange(1979.5,2022.5,1./12.)
    ax.plot(x_arr,total_month_merra2_ocean,color='w',linewidth=width,alpha=alpha)
    x_arr=np.arange(1978.5,2020.5,1./12.)
    ax.plot(x_arr,total_month_mswep_past_ocean,color=colors2[0],linewidth=width,alpha=alpha)#1
    x_arr=np.arange(1996.5,2022.5,1./12.)
    ax.plot(x_arr,total_month_gpcp_ocean,color=colors2[1],linewidth=width,alpha=alpha)
    x_arr=np.arange(2000.5,2020.5,1./12.)
    ax.plot(x_arr,total_month_gpcp3_ocean,color=colors2[2],linewidth=width,alpha=alpha)
    x_arr=np.arange(1982.5,2022.5,1./12.)
    ax.plot(x_arr,total_month_persiann_ocean,color=colors2[4],linewidth=width,alpha=alpha)
    x_arr=np.arange(2000.5,2022.5,1./12.)
    ax.plot(x_arr,total_month_imerg_ocean,color=colors2[3],linewidth=width,alpha=alpha)

width=6
alpha=1

ax.plot(np.arange(1940,2023,1),[x/12. for x in freq_list_era5_ocean],color='darkblue',linewidth=width,label=label_18,alpha=alpha)

ax.plot(np.arange(1958,2023,1),[x/12. for x in freq_list_jra55_ocean],color='dodgerblue',linewidth=width,label=label_17,alpha=0.75,zorder=204)


ax.plot(np.arange(1980,2023,1),[x/12. for x in freq_list_merra2_ocean],color='w',linewidth=width,label=label_16,alpha=alpha)


#ax.fill_between(np.arange(1900,2025,1),3,37,color='gray',alpha=0.8)#R95p
ax.fill_between(np.arange(1900,2025,1),0,0.3,color='gray',alpha=0.8)#R99p

if 1==1:
    ax.plot(np.arange(1979,2021,1),[x/12. for x in freq_list_mswep_past_ocean],color=colors2[0],linewidth=width,label=label_5,alpha=alpha)
    ax.plot(np.arange(1997,2023,1),[x/12. for x in freq_list_gpcp_ocean],color=colors2[1],linewidth=width,label=label_9,alpha=alpha,zorder=202)
    ax.plot(np.arange(2001,2021,1),[x/12. for x in freq_list_gpcp3_ocean],color=colors2[2],linewidth=width,label=label_15,alpha=alpha)
    ax.plot(np.arange(2001,2023,1),[x/12. for x in freq_list_imerg_ocean],color=colors2[3],linewidth=width,label=label_8,alpha=alpha)
    ax.plot(np.arange(1983,2023,1),[x/12. for x in freq_list_persiann_ocean],color=colors2[4],linewidth=width,label=label_6,alpha=alpha)

    ax.plot(1983,freq_list_persiann_land[0]/12.,marker='o',color='yellow',markersize=10)
    ax.plot(1985,freq_list_persiann_land[2]/12.,marker='o',color='yellow',markersize=10)



#ax.plot(np.arange(1940,2023,1),[x+2 for x in test],color='limegreen',linestyle='solid',linewidth=4,alpha=0.85,zorder=10)

#plt.axvline(x=1990,linewidth=3,linestyle='--',color='k')
#plt.axvline(x=2021,linewidth=3,linestyle='--',color='k')

ax.tick_params(labelsize=20)
ax.set_xlabel('Year',fontsize=22)
ax.set_ylabel('days month$^{-1}$',fontsize=22)
#ax.set_title(r'$\bf{Wet}$'+' '+r'$\bf{day}$'+' '+r'$\bf{total}$',fontsize=34,pad=5)
#ax.set_title(r'$\bf{EP}$'+' '+r'$\bf{total}$',fontsize=34,pad=5)
#ax.set_title(r'$\bf{R99p}$',fontsize=34,pad=5)
ax.set_title(r'$\bf{F99p-}$'+' '+r'$\bf{ocean}$',fontsize=31,pad=5)
#ax.set_title(r'$\bf{R98p_{all}-}$'+' '+r'$\bf{ocean}$',fontsize=31,pad=5)
ax.grid(True,linewidth=2)
plt.legend(loc='upper left',fontsize=14.4,ncol=1)#16.4
#ax.set_xlim(1978.8,2022.2)
ax.set_xlim(1939.3,2023.6)
#ax.set_ylim(9,36.2)#R95p
#ax.set_ylim(1,13.7)#R99p
ax.set_ylim(0,0.3)#R95p
for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(1.75)

#ax.fill_between(np.arange(2021,2024,1),200,1150,color='gray',alpha=0.3)
plt.show()

# %%
month_days=[31,28.25,31,30,31,30,31,31,30,31,30,31]


yrs=np.arange(1983,2023,1)
for i in range(len(yrs)):
    if i==0:
        total_month_persiann_ocean=list(total_persiann_ocean_monthly[:,i])
    else:
        total_month_persiann_ocean=total_month_persiann_ocean+list(total_persiann_ocean_monthly[:,i])
        
yrs=np.arange(1979,2021,1)
for i in range(len(yrs)):
    if i==0:
        total_month_mswep_past_ocean=list(total_mswep_past_ocean_monthly[:,i])
    else:
        total_month_mswep_past_ocean=total_month_mswep_past_ocean+list(total_mswep_past_ocean_monthly[:,i])

yrs=np.arange(2001,2023,1)
for i in range(len(yrs)):
    if i==0:
        total_month_imerg_ocean=list(total_imerg_ocean_monthly[:,i])
    else:
        total_month_imerg_ocean=total_month_imerg_ocean+list(total_imerg_ocean_monthly[:,i])

yrs=np.arange(1997,2023,1)
for i in range(len(yrs)):
    if i==0:
        total_month_gpcp_ocean=list(total_gpcp_ocean_monthly[:,i])
    else:
        total_month_gpcp_ocean=total_month_gpcp_ocean+list(total_gpcp_ocean_monthly[:,i])
        
yrs=np.arange(2001,2021,1)
for i in range(len(yrs)):
    if i==0:
        total_month_gpcp3_ocean=list(total_gpcp3_ocean_monthly[:,i])
    else:
        total_month_gpcp3_ocean=total_month_gpcp3_ocean+list(total_gpcp3_ocean_monthly[:,i])
         
yrs=np.arange(1980,2023,1)
for i in range(len(yrs)):
    if i==0:
        total_month_merra2_ocean=list(total_merra2_ocean_monthly[:,i])
    else:
        total_month_merra2_ocean=total_month_merra2_ocean+list(total_merra2_ocean_monthly[:,i])
        
yrs=np.arange(1958,2023,1)
for i in range(len(yrs)):
    if i==0:
        total_month_jra55_ocean=list(total_jra55_ocean_monthly[:,i])
    else:
        total_month_jra55_ocean=total_month_jra55_ocean+list(total_jra55_ocean_monthly[:,i])
        
yrs=np.arange(1940,2023,1)
for i in range(len(yrs)):
    if i==0:
        total_month_era5_ocean=list(total_era5_ocean_monthly[:,i])
    else:
        total_month_era5_ocean=total_month_era5_ocean+list(total_era5_ocean_monthly[:,i])

test=[x/12. for x in total_list_mswep_past_ocean]

yrs=np.arange(1979,2021,1)
zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0]
select_values=[x[1] for x in zipped_years if x[1]>=0]
r=st.linregress(select_years,select_values)

change=r[0]*len(yrs)
mean=float(sum(select_values))/float(len(select_values))
if r[3]<=0.0351:
    label_5='MSWEP V2.8 (Mean='+str(round(mean,1))+', '+'$\Delta$='+r'$\bf{'+str(round(change,2))+'}$'+', p='+str(round(r[3],3))+')'
else:
    label_5='MSWEP V2.8 (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

if 1==1:
    test=[x/12. for x in total_list_persiann_ocean]
    
    yrs=np.arange(1983,2023,1)
    zipped_years=list(zip(yrs,test))
    select_years=[x[0] for x in zipped_years if x[1]>=0]
    select_values=[x[1] for x in zipped_years if x[1]>=0]
    r=st.linregress(select_years,select_values)

    change=r[0]*len(yrs)
    mean=float(sum(select_values))/float(len(select_values))
    if r[3]<=0.0351:
        label_6='PERSIANN-CDR (Mean='+str(round(mean,1))+', '+'$\Delta$='+r'$\bf{'+str(round(change,2))+'}$'+', p='+str(round(r[3],3))+')'
    else:
        label_6='PERSIANN-CDR (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'
    
    yrs=np.arange(2001,2023,1)
    test=[x/12. for x in total_list_imerg_ocean]
    r=st.linregress(yrs,test)
    change=r[0]*len(yrs)
    mean=float(sum(test))/float(len(test))
    if r[3]<=0.0351:
        label_8='IMERG V07a (Mean='+str(round(mean,1))+', '+'$\Delta$='+r'$\bf{'+str(round(change,2))+'}$'+', p='+str(round(r[3],3))+')'
    else:
        label_8='IMERG V07a (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

    yrs=np.arange(1997,2023,1)
    test=[x/12. for x in total_list_gpcp_ocean]
    r=st.linregress(yrs,test)
    change=r[0]*len(yrs)
    mean=float(sum(test))/float(len(test))
    if r[3]<=0.0351:
        label_9='GPCP Daily CDR (Mean='+str(round(mean,1))+', '+'$\Delta$='+r'$\bf{'+str(round(change,2))+'}$'+', p='+str(round(r[3],3))+')'
    else:
        label_9='GPCP Daily CDR (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

    yrs=np.arange(2001,2021,1)
    test=[x/12. for x in total_list_gpcp3_ocean]
    r=st.linregress(yrs,test)
    change=r[0]*len(yrs)
    mean=float(sum(test))/float(len(test))
    if r[3]<=0.0351:
        label_15='GPCP V3.2 (Mean='+str(round(mean,1))+', '+'$\Delta$='+r'$\bf{'+str(round(change,2))+'}$'+', p='+str(round(r[3],3))+')'
    else:
        label_15='GPCP V3.2 (Mean='+str(round(mean,1))+', '+str(round(change,2))+', p='+str(round(r[3],3))+')'

    
    yrs=np.arange(1980,2023,1)
    test=[x/12. for x in total_list_merra2_ocean]
    r=st.linregress(yrs,test)
    change=r[0]*len(yrs)
    mean=float(sum(test))/float(len(test))
    if r[3]<=0.0351:
        label_16='MERRA-2 (Mean='+str(round(mean,1))+', '+'$\Delta$='+r'$\bf{'+str(round(change,2))+'}$'+', p='+str(round(r[3],3))+')'
    else:
        label_16='MERRA-2 (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

    yrs=np.arange(1958,2023,1)
    test=[x/12. for x in total_list_jra55_ocean]
    r=st.linregress(yrs[22:],test[22:])
    change=r[0]*len(yrs[22:])
    mean=float(sum(test[22:]))/float(len(test[22:]))
    if r[3]<=0.0351:
        label_17='JRA-55 (Mean='+str(round(mean,1))+', '+'$\Delta$='+r'$\bf{'+str(round(change,2))+'}$'+', p='+str(round(r[3],3))+')'
    else:
        label_17='JRA-55 (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

    yrs=np.arange(1940,2023,1)
    test=[x/12. for x in total_list_era5_ocean]
    r=st.linregress(yrs[40:],test[40:])
    change=r[0]*len(yrs[40:])
    mean=float(sum(test[40:]))/float(len(test[40:]))
    if r[3]<=0.0351:
        label_18='ERA5 (Mean='+str(round(mean,1))+', '+'$\Delta$='+r'$\bf{'+str(round(change,2))+'}$'+', p='+str(round(r[3],3))+')'
    else:
        label_18='ERA5 (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

    
from matplotlib.colors import LinearSegmentedColormap
#cmap1=LinearSegmentedColormap.from_list('new_cmap',['k','grey','b','dodgerblue','mediumorchid','darkviolet'])
#cmap1=LinearSegmentedColormap.from_list('new_cmap',['k','darkgrey','b','dodgerblue','darkviolet','indigo'])
#cmap1=LinearSegmentedColormap.from_list('new_cmap',['k','b','dodgerblue','darkslategray','darkviolet','indigo'])
#cmap1=LinearSegmentedColormap.from_list('new_cmap',['k','darkblue','b','teal','darkviolet','indigo'])
cmap1=LinearSegmentedColormap.from_list('new_cmap',['k','darkblue','b','darkslategray','lightseagreen','indigo'])
#darkslategray
colors1=cmap1(np.linspace(0,1,6))

cmap2=LinearSegmentedColormap.from_list('new_cmap',['magenta','red','orange','yellow'])
#cmap2=LinearSegmentedColormap.from_list('new_cmap',['magenta','red','yellow','orange'])
colors2=cmap2(np.linspace(0,1,5))
#colors2=cmap2(np.linspace(0,1,3))
#fig=plt.figure(figsize=(16,12))
fig=plt.figure(figsize=(12,18))
ax=plt.subplot(1,1,1)

width=0.75
alpha=0.55
if 1==1:
    x_arr=np.arange(1939.5,2022.5,1./12.)
    ax.plot(x_arr,total_month_era5_ocean,color='darkblue',linewidth=width,alpha=alpha)
    x_arr=np.arange(1957.5,2022.5,1./12.)
    ax.plot(x_arr,total_month_jra55_ocean,color='dodgerblue',linewidth=width,alpha=alpha)
    x_arr=np.arange(1979.5,2022.5,1./12.)
    ax.plot(x_arr,total_month_merra2_ocean,color='w',linewidth=width,alpha=alpha)
    x_arr=np.arange(1978.5,2020.5,1./12.)
    ax.plot(x_arr,total_month_mswep_past_ocean,color=colors2[0],linewidth=width,alpha=alpha)#1
    x_arr=np.arange(1996.5,2022.5,1./12.)
    ax.plot(x_arr,total_month_gpcp_ocean,color=colors2[1],linewidth=width,alpha=alpha)
    x_arr=np.arange(2000.5,2020.5,1./12.)
    ax.plot(x_arr,total_month_gpcp3_ocean,color=colors2[2],linewidth=width,alpha=alpha)
    x_arr=np.arange(1982.5,2022.5,1./12.)
    ax.plot(x_arr,total_month_persiann_ocean,color=colors2[4],linewidth=width,alpha=alpha)
    x_arr=np.arange(2000.5,2022.5,1./12.)
    ax.plot(x_arr,total_month_imerg_ocean,color=colors2[3],linewidth=width,alpha=alpha)

width=6
alpha=1

ax.plot(np.arange(1940,2023,1),[x/12. for x in total_list_era5_ocean],color='darkblue',linewidth=width,label=label_18,alpha=alpha)

ax.plot(np.arange(1958,2023,1),[x/12. for x in total_list_jra55_ocean],color='dodgerblue',linewidth=width,label=label_17,alpha=0.75,zorder=204)


ax.plot(np.arange(1980,2023,1),[x/12. for x in total_list_merra2_ocean],color='w',linewidth=width,label=label_16,alpha=alpha)


#ax.fill_between(np.arange(1900,2025,1),3,37,color='gray',alpha=0.8)#R95p
ax.fill_between(np.arange(1900,2025,1),0.2,14.5,color='gray',alpha=0.8)#R99p

if 1==1:
    ax.plot(np.arange(1979,2021,1),[x/12. for x in total_list_mswep_past_ocean],color=colors2[0],linewidth=width,label=label_5,alpha=alpha)
    ax.plot(np.arange(1997,2023,1),[x/12. for x in total_list_gpcp_ocean],color=colors2[1],linewidth=width,label=label_9,alpha=alpha,zorder=202)
    ax.plot(np.arange(2001,2021,1),[x/12. for x in total_list_gpcp3_ocean],color=colors2[2],linewidth=width,label=label_15,alpha=alpha)
    ax.plot(np.arange(2001,2023,1),[x/12. for x in total_list_imerg_ocean],color=colors2[3],linewidth=width,label=label_8,alpha=alpha)
    ax.plot(np.arange(1983,2023,1),[x/12. for x in total_list_persiann_ocean],color=colors2[4],linewidth=width,label=label_6,alpha=alpha)

    ax.plot(1983,total_list_persiann_land[0]/12.,marker='o',color='yellow',markersize=10)
    ax.plot(1985,total_list_persiann_land[2]/12.,marker='o',color='yellow',markersize=10)



#ax.plot(np.arange(1940,2023,1),[x+2 for x in test],color='limegreen',linestyle='solid',linewidth=4,alpha=0.85,zorder=10)

#plt.axvline(x=1990,linewidth=3,linestyle='--',color='k')
#plt.axvline(x=2021,linewidth=3,linestyle='--',color='k')

ax.tick_params(labelsize=20)
ax.set_xlabel('Year',fontsize=22)
ax.set_ylabel('mm month$^{-1}$',fontsize=22)
#ax.set_title(r'$\bf{Wet}$'+' '+r'$\bf{day}$'+' '+r'$\bf{total}$',fontsize=34,pad=5)
#ax.set_title(r'$\bf{EP}$'+' '+r'$\bf{total}$',fontsize=34,pad=5)
#ax.set_title(r'$\bf{R99p}$',fontsize=34,pad=5)
ax.set_title(r'$\bf{R99p-}$'+' '+r'$\bf{ocean}$',fontsize=31,pad=5)
#ax.set_title(r'$\bf{R98p_{all}-}$'+' '+r'$\bf{ocean}$',fontsize=31,pad=5)
ax.grid(True,linewidth=2)
plt.legend(loc='upper left',fontsize=14.4,ncol=1)#16.4
#ax.set_xlim(1978.8,2022.2)
ax.set_xlim(1939.3,2023.6)
#ax.set_ylim(9,36.2)#R95p
ax.set_ylim(1,13.7)#R99p
#ax.set_ylim(8,35.2)#R95p
for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(1.75)

#ax.fill_between(np.arange(2021,2024,1),200,1150,color='gray',alpha=0.3)
plt.show()

# %%
fig.savefig(dir_data+'big_precip_consensus_new_2b.png',dpi=300)

# %%
month_days=[31,28.25,31,30,31,30,31,31,30,31,30,31]


yrs=np.arange(1983,2023,1)
for i in range(len(yrs)):
    if i==0:
        total_month_persiann_land=list(total_persiann_land_monthly[:,i])
    else:
        total_month_persiann_land=total_month_persiann_land+list(total_persiann_land_monthly[:,i])
        
yrs=np.arange(1979,2023,1)
for i in range(len(yrs)):
    if i==0:
        total_month_cpc_land=list(total_cpc_land_monthly[:,i])
    else:
        total_month_cpc_land=total_month_cpc_land+list(total_cpc_land_monthly[:,i])

yrs=np.arange(1979,2021,1)
for i in range(len(yrs)):
    if i==0:
        total_month_mswep_past_land=list(total_mswep_past_land_monthly[:,i])
    else:
        total_month_mswep_past_land=total_month_mswep_past_land+list(total_mswep_past_land_monthly[:,i])

yrs=np.arange(2001,2023,1)
for i in range(len(yrs)):
    if i==0:
        total_month_imerg_land=list(total_imerg_land_monthly[:,i])
    else:
        total_month_imerg_land=total_month_imerg_land+list(total_imerg_land_monthly[:,i])

yrs=np.arange(1997,2023,1)
for i in range(len(yrs)):
    if i==0:
        total_month_gpcp_land=list(total_gpcp_land_monthly[:,i])
    else:
        total_month_gpcp_land=total_month_gpcp_land+list(total_gpcp_land_monthly[:,i])
        
yrs=np.arange(2001,2021,1)
for i in range(len(yrs)):
    if i==0:
        total_month_gpcp3_land=list(total_gpcp3_land_monthly[:,i])
    else:
        total_month_gpcp3_land=total_month_gpcp3_land+list(total_gpcp3_land_monthly[:,i])
        
yrs=np.arange(1950,2017,1)
for i in range(len(yrs)):
    if i==0:
        total_month_regen_land=list(total_regen_land_monthly[:,i])
    else:
        total_month_regen_land=total_month_regen_land+list(total_regen_land_monthly[:,i])
        
yrs=np.arange(1982,2021,1)
for i in range(len(yrs)):
    if i==0:
        total_month_gpcc_land=list(total_gpcc_land_monthly[:,i])
    else:
        total_month_gpcc_land=total_month_gpcc_land+list(total_gpcc_land_monthly[:,i])
        
yrs=np.arange(1980,2023,1)
for i in range(len(yrs)):
    if i==0:
        total_month_merra2_land=list(total_merra2_land_monthly[:,i])
    else:
        total_month_merra2_land=total_month_merra2_land+list(total_merra2_land_monthly[:,i])
        
yrs=np.arange(1958,2023,1)
for i in range(len(yrs)):
    if i==0:
        total_month_jra55_land=list(total_jra55_land_monthly[:,i])
    else:
        total_month_jra55_land=total_month_jra55_land+list(total_jra55_land_monthly[:,i])
        
yrs=np.arange(1940,2023,1)
for i in range(len(yrs)):
    if i==0:
        total_month_era5_land=list(total_era5_land_monthly[:,i])
    else:
        total_month_era5_land=total_month_era5_land+list(total_era5_land_monthly[:,i])

test=[x/12. for x in total_list_mswep_past_land]

yrs=np.arange(1979,2021,1)
zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0]
select_values=[x[1] for x in zipped_years if x[1]>=0]
r=st.linregress(select_years,select_values)

change=r[0]*len(yrs)
mean=float(sum(select_values))/float(len(select_values))
if r[3]<=0.0351:
    label_5='MSWEP V2.8 (Mean='+str(round(mean,1))+', '+'$\Delta$='+r'$\bf{'+str(round(change,2))+'}$'+', p='+str(round(r[3],3))+')'
else:
    label_5='MSWEP V2.8 (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

if 1==1:
    test=[x/12. for x in total_list_persiann_land]
    
    yrs=np.arange(1983,2023,1)
    zipped_years=list(zip(yrs,test))
    select_years=[x[0] for x in zipped_years if x[1]>=0]
    select_values=[x[1] for x in zipped_years if x[1]>=0]
    r=st.linregress(select_years,select_values)

    change=r[0]*len(yrs)
    mean=float(sum(select_values))/float(len(select_values))
    if r[3]<=0.0351:
        label_6='PERSIANN-CDR (Mean='+str(round(mean,1))+', '+'$\Delta$='+r'$\bf{'+str(round(change,2))+'}$'+', p='+str(round(r[3],3))+')'
    else:
        label_6='PERSIANN-CDR (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'
    
    yrs=np.arange(1979,2024,1)
    test=[x/12. for x in total_list_cpc_land]
    r=st.linregress(yrs[1:-1],test[1:-1])
    change=r[0]*len(yrs[1:-1])
    mean=float(sum(test[1:-1]))/float(len(test[1:-1]))
    if r[3]<=0.0351:
        label_7='CPC Unified (Mean='+str(round(mean,1))+', '+'$\Delta$='+r'$\bf{'+str(round(change,2))+'}$'+', p='+str(round(r[3],3))+')'
    else:
        label_7='CPC Unified (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

    yrs=np.arange(2001,2023,1)
    test=[x/12. for x in total_list_imerg_land]
    r=st.linregress(yrs,test)
    change=r[0]*len(yrs)
    mean=float(sum(test))/float(len(test))
    if r[3]<=0.0351:
        label_8='IMERG V07a (Mean='+str(round(mean,1))+', '+'$\Delta$='+r'$\bf{'+str(round(change,2))+'}$'+', p='+str(round(r[3],3))+')'
    else:
        label_8='IMERG V07a (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

    yrs=np.arange(1997,2023,1)
    test=[x/12. for x in total_list_gpcp_land]
    r=st.linregress(yrs,test)
    change=r[0]*len(yrs)
    mean=float(sum(test))/float(len(test))
    if r[3]<=0.0351:
        label_9='GPCP Daily CDR (Mean='+str(round(mean,1))+', '+'$\Delta$='+r'$\bf{'+str(round(change,2))+'}$'+', p='+str(round(r[3],3))+')'
    else:
        label_9='GPCP Daily CDR (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

    yrs=np.arange(1950,2017,1)
    test=[x/12. for x in total_list_regen_land]
    r=st.linregress(yrs[30:],test[30:])
    change=r[0]*len(yrs[30:])
    mean=float(sum(test[30:]))/float(len(test[30:]))
    if r[3]<=0.0351:
        label_10='REGEN (Mean='+str(round(mean,1))+', '+'$\Delta$='+r'$\bf{'+str(round(change,2))+'}$'+', p='+str(round(r[3],3))+')'
    else:
        label_10='REGEN (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

    yrs=np.arange(1982,2021,1)
    test=[x/12. for x in total_list_gpcc_land]
    r=st.linregress(yrs,test)
    change=r[0]*len(yrs)
    mean=float(sum(test))/float(len(test))
    if r[3]<=0.0351:
        label_11='GPCC V2022 (Mean='+str(round(mean,1))+', '+'$\Delta$='+r'$\bf{'+str(round(change,2))+'}$'+', p='+str(round(r[3],3))+')'
    else:
        label_11='GPCC V2022 (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

    yrs=np.arange(1940,2019,1)
    test=[x/12. for x in starting_40]
    r=st.linregress(yrs[40:],test[40:])
    change=r[0]*len(yrs[40:])
    mean=float(sum(test[40:]))/float(len(test[40:]))
    if r[3]<=0.0351:
        label_14='HadEX3 90% 1940 (Mean='+str(round(mean,1))+', '+'$\Delta$='+r'$\bf{'+str(round(change,2))+'}$'+', p='+str(round(r[3],3))+')'
    else:
        label_14='HadEX3 90% 1940 (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

    yrs=np.arange(2001,2021,1)
    test=[x/12. for x in total_list_gpcp3_land]
    r=st.linregress(yrs,test)
    change=r[0]*len(yrs)
    mean=float(sum(test))/float(len(test))
    if r[3]<=0.0351:
        label_15='GPCP V3.2 (Mean='+str(round(mean,1))+', '+'$\Delta$='+r'$\bf{'+str(round(change,2))+'}$'+', p='+str(round(r[3],3))+')'
    else:
        label_15='GPCP V3.2 (Mean='+str(round(mean,1))+', '+str(round(change,2))+', p='+str(round(r[3],3))+')'

    
    yrs=np.arange(1980,2023,1)
    test=[x/12. for x in total_list_merra2_land]
    r=st.linregress(yrs,test)
    change=r[0]*len(yrs)
    mean=float(sum(test))/float(len(test))
    if r[3]<=0.0351:
        label_16='MERRA-2 (Mean='+str(round(mean,1))+', '+'$\Delta$='+r'$\bf{'+str(round(change,2))+'}$'+', p='+str(round(r[3],3))+')'
    else:
        label_16='MERRA-2 (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

    yrs=np.arange(1958,2023,1)
    test=[x/12. for x in total_list_jra55_land]
    r=st.linregress(yrs[22:],test[22:])
    change=r[0]*len(yrs[22:])
    mean=float(sum(test[22:]))/float(len(test[22:]))
    if r[3]<=0.0351:
        label_17='JRA-55 (Mean='+str(round(mean,1))+', '+'$\Delta$='+r'$\bf{'+str(round(change,2))+'}$'+', p='+str(round(r[3],3))+')'
    else:
        label_17='JRA-55 (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

    yrs=np.arange(1940,2023,1)
    test=[x/12. for x in total_list_era5_land]
    r=st.linregress(yrs[40:],test[40:])
    change=r[0]*len(yrs[40:])
    mean=float(sum(test[40:]))/float(len(test[40:]))
    if r[3]<=0.0351:
        label_18='ERA5 (Mean='+str(round(mean,1))+', '+'$\Delta$='+r'$\bf{'+str(round(change,2))+'}$'+', p='+str(round(r[3],3))+')'
    else:
        label_18='ERA5 (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

    
from matplotlib.colors import LinearSegmentedColormap
#cmap1=LinearSegmentedColormap.from_list('new_cmap',['k','grey','b','dodgerblue','mediumorchid','darkviolet'])
#cmap1=LinearSegmentedColormap.from_list('new_cmap',['k','darkgrey','b','dodgerblue','darkviolet','indigo'])
#cmap1=LinearSegmentedColormap.from_list('new_cmap',['k','b','dodgerblue','darkslategray','darkviolet','indigo'])
#cmap1=LinearSegmentedColormap.from_list('new_cmap',['k','darkblue','b','teal','darkviolet','indigo'])
cmap1=LinearSegmentedColormap.from_list('new_cmap',['k','darkblue','b','darkslategray','lightseagreen','indigo'])
#darkslategray
colors1=cmap1(np.linspace(0,1,6))

cmap2=LinearSegmentedColormap.from_list('new_cmap',['magenta','red','orange','yellow'])
#cmap2=LinearSegmentedColormap.from_list('new_cmap',['magenta','red','yellow','orange'])
colors2=cmap2(np.linspace(0,1,5))
#colors2=cmap2(np.linspace(0,1,3))
#fig=plt.figure(figsize=(16,12))
fig=plt.figure(figsize=(12,18))
ax=plt.subplot(1,1,1)

width=0.75
if 1==1:
   
    x_arr=np.arange(1949.5,2016.5,1./12.)
    ax.plot(x_arr,total_month_regen_land,color='b',linewidth=width,alpha=0.55)
    x_arr=np.arange(1978.5,2022.5,1./12.)
    ax.plot(x_arr,total_month_cpc_land,color='darkturquoise',linewidth=1.1,alpha=0.55)
    x_arr=np.arange(1981.5,2020.5,1./12.)
    ax.plot(x_arr,total_month_gpcc_land,color='blueviolet',linewidth=width,alpha=0.55)

width=0.75
alpha=0.55
if 1==1:
    x_arr=np.arange(1939.5,2022.5,1./12.)
    ax.plot(x_arr,total_month_era5_land,color='darkblue',linewidth=width,alpha=alpha)
    x_arr=np.arange(1957.5,2022.5,1./12.)
    ax.plot(x_arr,total_month_jra55_land,color='dodgerblue',linewidth=width,alpha=alpha)
    x_arr=np.arange(1979.5,2022.5,1./12.)
    ax.plot(x_arr,total_month_merra2_land,color='w',linewidth=width,alpha=alpha)
    x_arr=np.arange(1978.5,2020.5,1./12.)
    ax.plot(x_arr,total_month_mswep_past_land,color=colors2[0],linewidth=width,alpha=alpha)#1
    x_arr=np.arange(1996.5,2022.5,1./12.)
    ax.plot(x_arr,total_month_gpcp_land,color=colors2[1],linewidth=width,alpha=alpha)
    x_arr=np.arange(2000.5,2020.5,1./12.)
    ax.plot(x_arr,total_month_gpcp3_land,color=colors2[2],linewidth=width,alpha=alpha)
    x_arr=np.arange(1982.5,2022.5,1./12.)
    ax.plot(x_arr,total_month_persiann_land,color=colors2[4],linewidth=width,alpha=alpha)
    x_arr=np.arange(2000.5,2022.5,1./12.)
    ax.plot(x_arr,total_month_imerg_land,color=colors2[3],linewidth=width,alpha=alpha)

width=6
alpha=1
ax.plot(np.arange(1940,2019,1),[x/12. for x in starting_40],color='k',linewidth=width,label=label_14)
ax.plot(np.arange(1940,2023,1),[x/12. for x in total_list_era5_land],color='darkblue',linewidth=width,label=label_18,alpha=alpha)
ax.plot(np.arange(1950,2017,1),[x/12. for x in total_list_regen_land],color='b',linewidth=width,label=label_10,zorder=200)
ax.plot(np.arange(1958,2023,1),[x/12. for x in total_list_jra55_land],color='dodgerblue',linewidth=width,label=label_17,alpha=0.75,zorder=204)
ax.plot(np.arange(1979,2024,1),[x/12. for x in total_list_cpc_land],color='darkturquoise',linewidth=width,label=label_7,zorder=201)
ax.plot(np.arange(1982,2021,1),[x/12. for x in total_list_gpcc_land],color='blueviolet',linewidth=width,label=label_11)
ax.plot(np.arange(1980,2023,1),[x/12. for x in total_list_merra2_land],color='w',linewidth=width,label=label_16,alpha=alpha)


#ax.fill_between(np.arange(1900,2025,1),3,37,color='gray',alpha=0.8)#R95p
ax.fill_between(np.arange(1900,2025,1),0,13.5,color='gray',alpha=0.8)#R99p

if 1==1:
    ax.plot(np.arange(1979,2021,1),[x/12. for x in total_list_mswep_past_land],color=colors2[0],linewidth=width,label=label_5,alpha=alpha)
    ax.plot(np.arange(1997,2023,1),[x/12. for x in total_list_gpcp_land],color=colors2[1],linewidth=width,label=label_9,alpha=alpha,zorder=202)
    ax.plot(np.arange(2001,2021,1),[x/12. for x in total_list_gpcp3_land],color=colors2[2],linewidth=width,label=label_15,alpha=alpha)
    ax.plot(np.arange(2001,2023,1),[x/12. for x in total_list_imerg_land],color=colors2[3],linewidth=width,label=label_8,alpha=alpha)
    ax.plot(np.arange(1983,2023,1),[x/12. for x in total_list_persiann_land],color=colors2[4],linewidth=width,label=label_6,alpha=alpha)

    ax.plot(1983,total_list_persiann_land[0]/12.,marker='o',color='yellow',markersize=10)
    ax.plot(1985,total_list_persiann_land[2]/12.,marker='o',color='yellow',markersize=10)



#ax.plot(np.arange(1940,2023,1),[x+2 for x in test],color='limegreen',linestyle='solid',linewidth=4,alpha=0.85,zorder=10)

#plt.axvline(x=1990,linewidth=3,linestyle='--',color='k')
#plt.axvline(x=2021,linewidth=3,linestyle='--',color='k')

ax.tick_params(labelsize=20)
ax.set_xlabel('Year',fontsize=22)
ax.set_ylabel('mm month$^{-1}$',fontsize=22)
#ax.set_title(r'$\bf{Wet}$'+' '+r'$\bf{day}$'+' '+r'$\bf{total}$',fontsize=34,pad=5)
#ax.set_title(r'$\bf{EP}$'+' '+r'$\bf{total}$',fontsize=34,pad=5)
#ax.set_title(r'$\bf{R99p}$',fontsize=34,pad=5)
ax.set_title(r'$\bf{R99p-}$'+' '+r'$\bf{REGEN}$'+' '+r'$\bf{HQ}$'+' '+r'$\bf{region}$',fontsize=31,pad=5)
#ax.set_title(r'$\bf{R98p_{all}-}$'+' '+r'$\bf{REGEN}$'+' '+r'$\bf{HQ}$'+' '+r'$\bf{region}$',fontsize=31,pad=5)
ax.grid(True,linewidth=2)
plt.legend(loc='upper left',fontsize=14.4,ncol=1)#16.4
#ax.set_xlim(1978.8,2022.2)
ax.set_xlim(1939.3,2023.6)
#ax.set_ylim(4.5,31.7)#R95p
ax.set_ylim(0,13.5)#R99p
for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(1.75)

#ax.fill_between(np.arange(2021,2024,1),200,1150,color='gray',alpha=0.3)
plt.show()

# %%
fig.savefig(dir_data+'big_precip_consensus_new_3b.png',dpi=300)
