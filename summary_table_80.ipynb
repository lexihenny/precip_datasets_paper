# %%
import numpy as np
import xarray as xr
import scipy.stats as st
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import requests
import os,errno
import sys
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER,LATITUDE_FORMATTER
import matplotlib.ticker as mticker
import cartopy.feature as cfeature
import datetime as dt
import pandas as pd
import time
import urllib.request
import metpy.calc as mpcalc
import salem
import scipy.optimize as opt
import warnings
import geopy.distance
import matplotlib as mpl
import matplotlib.colors as mcolors
from matplotlib.lines import Line2D
import matplotlib.backends.backend_pdf

from scipy.ndimage.measurements import label
from scipy.ndimage import binary_dilation

warnings.filterwarnings('ignore')

# %matplotlib inline

dir_data='/Users/ahenny/'
dir1='/Volumes/LaCie/'
dir2='/Volumes/Extreme Pro/'
dir3='/Volumes/My Passport/day/'

# %%
ds=xr.open_dataset(dir_data+'precip_datasets_compare_persiann_wet_6070_test.nc')
total_list_persiann_ocean_wet=ds['total_list_persiann_ocean'].values.tolist()[:]
total_list_persiann_land_wet=ds['total_list_persiann_land'].values.tolist()[:]
freq_list_persiann_ocean_wet=ds['freq_list_persiann_ocean'].values.tolist()[:]
freq_list_persiann_land_wet=ds['freq_list_persiann_land'].values.tolist()[:]
intensity_list_persiann_ocean_wet=ds['intensity_list_persiann_ocean'].values.tolist()[:]
intensity_list_persiann_land_wet=ds['intensity_list_persiann_land'].values.tolist()[:]

ds=xr.open_dataset(dir_data+'precip_datasets_compare_persiann_x_6070_test.nc')
total_list_persiann_ocean_98=ds['total_list_persiann_ocean'].values.tolist()[:]
total_list_persiann_land_98=ds['total_list_persiann_land'].values.tolist()[:]
freq_list_persiann_ocean_98=ds['freq_list_persiann_ocean'].values.tolist()[:]
freq_list_persiann_land_98=ds['freq_list_persiann_land'].values.tolist()[:]
intensity_list_persiann_ocean_98=ds['intensity_list_persiann_ocean'].values.tolist()[:]
intensity_list_persiann_land_98=ds['intensity_list_persiann_land'].values.tolist()[:]

ds=xr.open_dataset(dir_data+'precip_datasets_compare_persiann_r95p_6070_test.nc')
total_list_persiann_ocean_95=ds['total_list_persiann_ocean'].values.tolist()[:]
total_list_persiann_land_95=ds['total_list_persiann_land'].values.tolist()[:]
freq_list_persiann_ocean_95=ds['freq_list_persiann_ocean'].values.tolist()[:]
freq_list_persiann_land_95=ds['freq_list_persiann_land'].values.tolist()[:]
intensity_list_persiann_ocean_95=ds['intensity_list_persiann_ocean'].values.tolist()[:]
intensity_list_persiann_land_95=ds['intensity_list_persiann_land'].values.tolist()[:]

ds=xr.open_dataset(dir_data+'precip_datasets_compare_persiann_r99p_6070_test.nc')
total_list_persiann_ocean_99=ds['total_list_persiann_ocean'].values.tolist()[:]
total_list_persiann_land_99=ds['total_list_persiann_land'].values.tolist()[:]
freq_list_persiann_ocean_99=ds['freq_list_persiann_ocean'].values.tolist()[:]
freq_list_persiann_land_99=ds['freq_list_persiann_land'].values.tolist()[:]
intensity_list_persiann_ocean_99=ds['intensity_list_persiann_ocean'].values.tolist()[:]
intensity_list_persiann_land_99=ds['intensity_list_persiann_land'].values.tolist()[:]

# %%
ds=xr.open_dataset(dir_data+'precip_datasets_compare_mswep_past_wet_6070_test.nc')
total_list_mswep_past_ocean_wet=ds['total_list_mswep_past_ocean'].values.tolist()[1:]
total_list_mswep_past_land_wet=ds['total_list_mswep_past_land'].values.tolist()[1:]
freq_list_mswep_past_ocean_wet=ds['freq_list_mswep_past_ocean'].values.tolist()[1:]
freq_list_mswep_past_land_wet=ds['freq_list_mswep_past_land'].values.tolist()[1:]
intensity_list_mswep_past_ocean_wet=ds['intensity_list_mswep_past_ocean'].values.tolist()[1:]
intensity_list_mswep_past_land_wet=ds['intensity_list_mswep_past_land'].values.tolist()[1:]

ds=xr.open_dataset(dir_data+'precip_datasets_compare_mswep_past_x_6070_test.nc')
total_list_mswep_past_ocean_98=ds['total_list_mswep_past_ocean'].values.tolist()[1:]
total_list_mswep_past_land_98=ds['total_list_mswep_past_land'].values.tolist()[1:]
freq_list_mswep_past_ocean_98=ds['freq_list_mswep_past_ocean'].values.tolist()[1:]
freq_list_mswep_past_land_98=ds['freq_list_mswep_past_land'].values.tolist()[1:]
intensity_list_mswep_past_ocean_98=ds['intensity_list_mswep_past_ocean'].values.tolist()[1:]
intensity_list_mswep_past_land_98=ds['intensity_list_mswep_past_land'].values.tolist()[1:]

ds=xr.open_dataset(dir_data+'precip_datasets_compare_mswep_past_r95p_6070_test.nc')
total_list_mswep_past_ocean_95=ds['total_list_mswep_past_ocean'].values.tolist()[1:]
total_list_mswep_past_land_95=ds['total_list_mswep_past_land'].values.tolist()[1:]
freq_list_mswep_past_ocean_95=ds['freq_list_mswep_past_ocean'].values.tolist()[1:]
freq_list_mswep_past_land_95=ds['freq_list_mswep_past_land'].values.tolist()[1:]
intensity_list_mswep_past_ocean_95=ds['intensity_list_mswep_past_ocean'].values.tolist()[1:]
intensity_list_mswep_past_land_95=ds['intensity_list_mswep_past_land'].values.tolist()[1:]

ds=xr.open_dataset(dir_data+'precip_datasets_compare_mswep_past_r99p_6070_test.nc')
total_list_mswep_past_ocean_99=ds['total_list_mswep_past_ocean'].values.tolist()[1:]
total_list_mswep_past_land_99=ds['total_list_mswep_past_land'].values.tolist()[1:]
freq_list_mswep_past_ocean_99=ds['freq_list_mswep_past_ocean'].values.tolist()[1:]
freq_list_mswep_past_land_99=ds['freq_list_mswep_past_land'].values.tolist()[1:]
intensity_list_mswep_past_ocean_99=ds['intensity_list_mswep_past_ocean'].values.tolist()[1:]
intensity_list_mswep_past_land_99=ds['intensity_list_mswep_past_land'].values.tolist()[1:]

# %%
ds=xr.open_dataset(dir_data+'precip_datasets_compare_cpc_wet_6070_test.nc')
total_list_cpc_land_wet=ds['total_list_cpc_land'].values.tolist()[1:]
freq_list_cpc_land_wet=ds['freq_list_cpc_land'].values.tolist()[1:]
intensity_list_cpc_land_wet=ds['intensity_list_cpc_land'].values.tolist()[1:]

ds=xr.open_dataset(dir_data+'precip_datasets_compare_cpc_x_6070_test.nc')
total_list_cpc_land_98=ds['total_list_cpc_land'].values.tolist()[1:]
freq_list_cpc_land_98=ds['freq_list_cpc_land'].values.tolist()[1:]
intensity_list_cpc_land_98=ds['intensity_list_cpc_land'].values.tolist()[1:]

ds=xr.open_dataset(dir_data+'precip_datasets_compare_cpc_r95p_6070_test.nc')
total_list_cpc_land_95=ds['total_list_cpc_land'].values.tolist()[1:]
freq_list_cpc_land_95=ds['freq_list_cpc_land'].values.tolist()[1:]
intensity_list_cpc_land_95=ds['intensity_list_cpc_land'].values.tolist()[1:]

ds=xr.open_dataset(dir_data+'precip_datasets_compare_cpc_r99p_6070_test.nc')
total_list_cpc_land_99=ds['total_list_cpc_land'].values.tolist()[1:]
freq_list_cpc_land_99=ds['freq_list_cpc_land'].values.tolist()[1:]
intensity_list_cpc_land_99=ds['intensity_list_cpc_land'].values.tolist()[1:]

# %%
ds=xr.open_dataset(dir_data+'precip_datasets_compare_gpcc_wet_6070_test.nc')
total_list_gpcc_land_wet=ds['total_list_gpcc_land'].values.tolist()[:]
freq_list_gpcc_land_wet=ds['freq_list_gpcc_land'].values.tolist()[:]
intensity_list_gpcc_land_wet=ds['intensity_list_gpcc_land'].values.tolist()[:]

ds=xr.open_dataset(dir_data+'precip_datasets_compare_gpcc_x_6070_test.nc')
total_list_gpcc_land_98=ds['total_list_gpcc_land'].values.tolist()[:]
freq_list_gpcc_land_98=ds['freq_list_gpcc_land'].values.tolist()[:]
intensity_list_gpcc_land_98=ds['intensity_list_gpcc_land'].values.tolist()[:]

ds=xr.open_dataset(dir_data+'precip_datasets_compare_gpcc_r95p_6070_test.nc')
total_list_gpcc_land_95=ds['total_list_gpcc_land'].values.tolist()[:]
freq_list_gpcc_land_95=ds['freq_list_gpcc_land'].values.tolist()[:]
intensity_list_gpcc_land_95=ds['intensity_list_gpcc_land'].values.tolist()[:]

ds=xr.open_dataset(dir_data+'precip_datasets_compare_gpcc_r99p_6070_test.nc')
total_list_gpcc_land_99=ds['total_list_gpcc_land'].values.tolist()[:]
freq_list_gpcc_land_99=ds['freq_list_gpcc_land'].values.tolist()[:]
intensity_list_gpcc_land_99=ds['intensity_list_gpcc_land'].values.tolist()[:]

# %%
ds=xr.open_dataset(dir_data+'precip_datasets_compare_regenfull_wet_6070_test.nc')
total_list_regen_land_wet=ds['total_list_regen_land'].values.tolist()[30:]
freq_list_regen_land_wet=ds['freq_list_regen_land'].values.tolist()[30:]
intensity_list_regen_land_wet=ds['intensity_list_regen_land'].values.tolist()[30:]

ds=xr.open_dataset(dir_data+'precip_datasets_compare_regenfull_x_6070_test.nc')
total_list_regen_land_98=ds['total_list_regen_land'].values.tolist()[30:]
freq_list_regen_land_98=ds['freq_list_regen_land'].values.tolist()[30:]
intensity_list_regen_land_98=ds['intensity_list_regen_land'].values.tolist()[30:]

ds=xr.open_dataset(dir_data+'precip_datasets_compare_regenfull_r95p_6070_test.nc')
total_list_regen_land_95=ds['total_list_regen_land'].values.tolist()[30:]
freq_list_regen_land_95=ds['freq_list_regen_land'].values.tolist()[30:]
intensity_list_regen_land_95=ds['intensity_list_regen_land'].values.tolist()[30:]

ds=xr.open_dataset(dir_data+'precip_datasets_compare_regenfull_r99p_6070_test.nc')
total_list_regen_land_99=ds['total_list_regen_land'].values.tolist()[30:]
freq_list_regen_land_99=ds['freq_list_regen_land'].values.tolist()[30:]
intensity_list_regen_land_99=ds['intensity_list_regen_land'].values.tolist()[30:]

# %%
ds=xr.open_dataset(dir_data+'precip_datasets_compare_imerg_wet_6070_test.nc')
total_list_imerg_ocean_wet=ds['total_list_imerg_ocean'].values.tolist()
total_list_imerg_land_wet=ds['total_list_imerg_land'].values.tolist()
freq_list_imerg_ocean_wet=ds['freq_list_imerg_ocean'].values.tolist()
freq_list_imerg_land_wet=ds['freq_list_imerg_land'].values.tolist()
intensity_list_imerg_ocean_wet=ds['intensity_list_imerg_ocean'].values.tolist()
intensity_list_imerg_land_wet=ds['intensity_list_imerg_land'].values.tolist()

ds=xr.open_dataset(dir_data+'precip_datasets_compare_imerg_x_6070_test.nc')
total_list_imerg_ocean_98=ds['total_list_imerg_ocean'].values.tolist()
total_list_imerg_land_98=ds['total_list_imerg_land'].values.tolist()
freq_list_imerg_ocean_98=ds['freq_list_imerg_ocean'].values.tolist()
freq_list_imerg_land_98=ds['freq_list_imerg_land'].values.tolist()
intensity_list_imerg_ocean_98=ds['intensity_list_imerg_ocean'].values.tolist()
intensity_list_imerg_land_98=ds['intensity_list_imerg_land'].values.tolist()

ds=xr.open_dataset(dir_data+'precip_datasets_compare_imerg_r95p_6070_test.nc')
total_list_imerg_ocean_95=ds['total_list_imerg_ocean'].values.tolist()
total_list_imerg_land_95=ds['total_list_imerg_land'].values.tolist()
freq_list_imerg_ocean_95=ds['freq_list_imerg_ocean'].values.tolist()
freq_list_imerg_land_95=ds['freq_list_imerg_land'].values.tolist()
intensity_list_imerg_ocean_95=ds['intensity_list_imerg_ocean'].values.tolist()
intensity_list_imerg_land_95=ds['intensity_list_imerg_land'].values.tolist()

ds=xr.open_dataset(dir_data+'precip_datasets_compare_imerg_r99p_6070_test.nc')
total_list_imerg_ocean_99=ds['total_list_imerg_ocean'].values.tolist()
total_list_imerg_land_99=ds['total_list_imerg_land'].values.tolist()
freq_list_imerg_ocean_99=ds['freq_list_imerg_ocean'].values.tolist()
freq_list_imerg_land_99=ds['freq_list_imerg_land'].values.tolist()
intensity_list_imerg_ocean_99=ds['intensity_list_imerg_ocean'].values.tolist()
intensity_list_imerg_land_99=ds['intensity_list_imerg_land'].values.tolist()

# %%
ds=xr.open_dataset(dir_data+'precip_datasets_compare_gpcp_wet_6070_test.nc')
total_list_gpcp_ocean_wet=ds['total_list_gpcp_ocean'].values.tolist()
total_list_gpcp_land_wet=ds['total_list_gpcp_land'].values.tolist()
freq_list_gpcp_ocean_wet=ds['freq_list_gpcp_ocean'].values.tolist()
freq_list_gpcp_land_wet=ds['freq_list_gpcp_land'].values.tolist()
intensity_list_gpcp_ocean_wet=ds['intensity_list_gpcp_ocean'].values.tolist()
intensity_list_gpcp_land_wet=ds['intensity_list_gpcp_land'].values.tolist()

ds=xr.open_dataset(dir_data+'precip_datasets_compare_gpcp_x_6070_test.nc')
total_list_gpcp_ocean_98=ds['total_list_gpcp_ocean'].values.tolist()
total_list_gpcp_land_98=ds['total_list_gpcp_land'].values.tolist()
freq_list_gpcp_ocean_98=ds['freq_list_gpcp_ocean'].values.tolist()
freq_list_gpcp_land_98=ds['freq_list_gpcp_land'].values.tolist()
intensity_list_gpcp_ocean_98=ds['intensity_list_gpcp_ocean'].values.tolist()
intensity_list_gpcp_land_98=ds['intensity_list_gpcp_land'].values.tolist()

ds=xr.open_dataset(dir_data+'precip_datasets_compare_gpcp_r95p_6070_test.nc')
total_list_gpcp_ocean_95=ds['total_list_gpcp_ocean'].values.tolist()
total_list_gpcp_land_95=ds['total_list_gpcp_land'].values.tolist()
freq_list_gpcp_ocean_95=ds['freq_list_gpcp_ocean'].values.tolist()
freq_list_gpcp_land_95=ds['freq_list_gpcp_land'].values.tolist()
intensity_list_gpcp_ocean_95=ds['intensity_list_gpcp_ocean'].values.tolist()
intensity_list_gpcp_land_95=ds['intensity_list_gpcp_land'].values.tolist()

ds=xr.open_dataset(dir_data+'precip_datasets_compare_gpcp_r99p_6070_test.nc')
total_list_gpcp_ocean_99=ds['total_list_gpcp_ocean'].values.tolist()
total_list_gpcp_land_99=ds['total_list_gpcp_land'].values.tolist()
freq_list_gpcp_ocean_99=ds['freq_list_gpcp_ocean'].values.tolist()
freq_list_gpcp_land_99=ds['freq_list_gpcp_land'].values.tolist()
intensity_list_gpcp_ocean_99=ds['intensity_list_gpcp_ocean'].values.tolist()
intensity_list_gpcp_land_99=ds['intensity_list_gpcp_land'].values.tolist()

# %%
ds=xr.open_dataset(dir_data+'precip_datasets_compare_gpcp3_wet_6070_test.nc')
total_list_gpcp3_ocean_wet=ds['total_list_gpcp3_ocean'].values.tolist()
total_list_gpcp3_land_wet=ds['total_list_gpcp3_land'].values.tolist()
freq_list_gpcp3_ocean_wet=ds['freq_list_gpcp3_ocean'].values.tolist()
freq_list_gpcp3_land_wet=ds['freq_list_gpcp3_land'].values.tolist()
intensity_list_gpcp3_ocean_wet=ds['intensity_list_gpcp3_ocean'].values.tolist()
intensity_list_gpcp3_land_wet=ds['intensity_list_gpcp3_land'].values.tolist()

ds=xr.open_dataset(dir_data+'precip_datasets_compare_gpcp3_x_6070_test.nc')
total_list_gpcp3_ocean_98=ds['total_list_gpcp3_ocean'].values.tolist()
total_list_gpcp3_land_98=ds['total_list_gpcp3_land'].values.tolist()
freq_list_gpcp3_ocean_98=ds['freq_list_gpcp3_ocean'].values.tolist()
freq_list_gpcp3_land_98=ds['freq_list_gpcp3_land'].values.tolist()
intensity_list_gpcp3_ocean_98=ds['intensity_list_gpcp3_ocean'].values.tolist()
intensity_list_gpcp3_land_98=ds['intensity_list_gpcp3_land'].values.tolist()

ds=xr.open_dataset(dir_data+'precip_datasets_compare_gpcp3_r95p_6070_test.nc')
total_list_gpcp3_ocean_95=ds['total_list_gpcp3_ocean'].values.tolist()
total_list_gpcp3_land_95=ds['total_list_gpcp3_land'].values.tolist()
freq_list_gpcp3_ocean_95=ds['freq_list_gpcp3_ocean'].values.tolist()
freq_list_gpcp3_land_95=ds['freq_list_gpcp3_land'].values.tolist()
intensity_list_gpcp3_ocean_95=ds['intensity_list_gpcp3_ocean'].values.tolist()
intensity_list_gpcp3_land_95=ds['intensity_list_gpcp3_land'].values.tolist()

ds=xr.open_dataset(dir_data+'precip_datasets_compare_gpcp3_r99p_6070_test.nc')
total_list_gpcp3_ocean_99=ds['total_list_gpcp3_ocean'].values.tolist()
total_list_gpcp3_land_99=ds['total_list_gpcp3_land'].values.tolist()
freq_list_gpcp3_ocean_99=ds['freq_list_gpcp3_ocean'].values.tolist()
freq_list_gpcp3_land_99=ds['freq_list_gpcp3_land'].values.tolist()
intensity_list_gpcp3_ocean_99=ds['intensity_list_gpcp3_ocean'].values.tolist()
intensity_list_gpcp3_land_99=ds['intensity_list_gpcp3_land'].values.tolist()

# %%
ds=xr.open_dataset(dir_data+'precip_datasets_compare_merra2_wet_6070_test.nc')
total_list_merra2_ocean_wet=ds['total_list_merra2_ocean'].values.tolist()[:]
total_list_merra2_land_wet=ds['total_list_merra2_land'].values.tolist()[:]
freq_list_merra2_ocean_wet=ds['freq_list_merra2_ocean'].values.tolist()[:]
freq_list_merra2_land_wet=ds['freq_list_merra2_land'].values.tolist()[:]
intensity_list_merra2_ocean_wet=ds['intensity_list_merra2_ocean'].values.tolist()[:]
intensity_list_merra2_land_wet=ds['intensity_list_merra2_land'].values.tolist()[:]

ds=xr.open_dataset(dir_data+'precip_datasets_compare_merra2_x_6070_test.nc')
total_list_merra2_ocean_98=ds['total_list_merra2_ocean'].values.tolist()[:]
total_list_merra2_land_98=ds['total_list_merra2_land'].values.tolist()[:]
freq_list_merra2_ocean_98=ds['freq_list_merra2_ocean'].values.tolist()[:]
freq_list_merra2_land_98=ds['freq_list_merra2_land'].values.tolist()[:]
intensity_list_merra2_ocean_98=ds['intensity_list_merra2_ocean'].values.tolist()[:]
intensity_list_merra2_land_98=ds['intensity_list_merra2_land'].values.tolist()[:]

ds=xr.open_dataset(dir_data+'precip_datasets_compare_merra2_r95p_6070_test.nc')
total_list_merra2_ocean_95=ds['total_list_merra2_ocean'].values.tolist()[:]
total_list_merra2_land_95=ds['total_list_merra2_land'].values.tolist()[:]
freq_list_merra2_ocean_95=ds['freq_list_merra2_ocean'].values.tolist()[:]
freq_list_merra2_land_95=ds['freq_list_merra2_land'].values.tolist()[:]
intensity_list_merra2_ocean_95=ds['intensity_list_merra2_ocean'].values.tolist()[:]
intensity_list_merra2_land_95=ds['intensity_list_merra2_land'].values.tolist()[:]

ds=xr.open_dataset(dir_data+'precip_datasets_compare_merra2_r99p_6070_test.nc')
total_list_merra2_ocean_99=ds['total_list_merra2_ocean'].values.tolist()[:]
total_list_merra2_land_99=ds['total_list_merra2_land'].values.tolist()[:]
freq_list_merra2_ocean_99=ds['freq_list_merra2_ocean'].values.tolist()[:]
freq_list_merra2_land_99=ds['freq_list_merra2_land'].values.tolist()[:]
intensity_list_merra2_ocean_99=ds['intensity_list_merra2_ocean'].values.tolist()[:]
intensity_list_merra2_land_99=ds['intensity_list_merra2_land'].values.tolist()[:]

# %%
ds=xr.open_dataset(dir_data+'precip_datasets_compare_jra55_wet_6070_test.nc')
total_list_jra55_ocean_wet=ds['total_list_jra55_ocean'].values.tolist()[22:]
total_list_jra55_land_wet=ds['total_list_jra55_land'].values.tolist()[22:]
freq_list_jra55_ocean_wet=ds['freq_list_jra55_ocean'].values.tolist()[22:]
freq_list_jra55_land_wet=ds['freq_list_jra55_land'].values.tolist()[22:]
intensity_list_jra55_ocean_wet=ds['intensity_list_jra55_ocean'].values.tolist()[22:]
intensity_list_jra55_land_wet=ds['intensity_list_jra55_land'].values.tolist()[22:]

ds=xr.open_dataset(dir_data+'precip_datasets_compare_jra55_x_6070_test.nc')
total_list_jra55_ocean_98=ds['total_list_jra55_ocean'].values.tolist()[22:]
total_list_jra55_land_98=ds['total_list_jra55_land'].values.tolist()[22:]
freq_list_jra55_ocean_98=ds['freq_list_jra55_ocean'].values.tolist()[22:]
freq_list_jra55_land_98=ds['freq_list_jra55_land'].values.tolist()[22:]
intensity_list_jra55_ocean_98=ds['intensity_list_jra55_ocean'].values.tolist()[22:]
intensity_list_jra55_land_98=ds['intensity_list_jra55_land'].values.tolist()[22:]

ds=xr.open_dataset(dir_data+'precip_datasets_compare_jra55_r95p_6070_test.nc')
total_list_jra55_ocean_95=ds['total_list_jra55_ocean'].values.tolist()[22:]
total_list_jra55_land_95=ds['total_list_jra55_land'].values.tolist()[22:]
freq_list_jra55_ocean_95=ds['freq_list_jra55_ocean'].values.tolist()[22:]
freq_list_jra55_land_95=ds['freq_list_jra55_land'].values.tolist()[22:]
intensity_list_jra55_ocean_95=ds['intensity_list_jra55_ocean'].values.tolist()[22:]
intensity_list_jra55_land_95=ds['intensity_list_jra55_land'].values.tolist()[22:]

ds=xr.open_dataset(dir_data+'precip_datasets_compare_jra55_r99p_6070_test.nc')
total_list_jra55_ocean_99=ds['total_list_jra55_ocean'].values.tolist()[22:]
total_list_jra55_land_99=ds['total_list_jra55_land'].values.tolist()[22:]
freq_list_jra55_ocean_99=ds['freq_list_jra55_ocean'].values.tolist()[22:]
freq_list_jra55_land_99=ds['freq_list_jra55_land'].values.tolist()[22:]
intensity_list_jra55_ocean_99=ds['intensity_list_jra55_ocean'].values.tolist()[22:]
intensity_list_jra55_land_99=ds['intensity_list_jra55_land'].values.tolist()[22:]

# %%
ds=xr.open_dataset(dir_data+'precip_datasets_compare_era5_wet_6070_test.nc')
total_list_era5_ocean_wet=ds['total_list_era5_ocean'].values.tolist()[40:]
total_list_era5_land_wet=ds['total_list_era5_land'].values.tolist()[40:]
freq_list_era5_ocean_wet=ds['freq_list_era5_ocean'].values.tolist()[40:]
freq_list_era5_land_wet=ds['freq_list_era5_land'].values.tolist()[40:]
intensity_list_era5_ocean_wet=ds['intensity_list_era5_ocean'].values.tolist()[40:]
intensity_list_era5_land_wet=ds['intensity_list_era5_land'].values.tolist()[40:]

ds=xr.open_dataset(dir_data+'precip_datasets_compare_era5_x_6070_test.nc')
total_list_era5_ocean_98=ds['total_list_era5_ocean'].values.tolist()[40:]
total_list_era5_land_98=ds['total_list_era5_land'].values.tolist()[40:]
freq_list_era5_ocean_98=ds['freq_list_era5_ocean'].values.tolist()[40:]
freq_list_era5_land_98=ds['freq_list_era5_land'].values.tolist()[40:]
intensity_list_era5_ocean_98=ds['intensity_list_era5_ocean'].values.tolist()[40:]
intensity_list_era5_land_98=ds['intensity_list_era5_land'].values.tolist()[40:]

ds=xr.open_dataset(dir_data+'precip_datasets_compare_era5_r95p_6070_test.nc')
total_list_era5_ocean_95=ds['total_list_era5_ocean'].values.tolist()[40:]
total_list_era5_land_95=ds['total_list_era5_land'].values.tolist()[40:]
freq_list_era5_ocean_95=ds['freq_list_era5_ocean'].values.tolist()[40:]
freq_list_era5_land_95=ds['freq_list_era5_land'].values.tolist()[40:]
intensity_list_era5_ocean_95=ds['intensity_list_era5_ocean'].values.tolist()[40:]
intensity_list_era5_land_95=ds['intensity_list_era5_land'].values.tolist()[40:]

ds=xr.open_dataset(dir_data+'precip_datasets_compare_era5_r99p_6070_test.nc')
total_list_era5_ocean_99=ds['total_list_era5_ocean'].values.tolist()[40:]
total_list_era5_land_99=ds['total_list_era5_land'].values.tolist()[40:]
freq_list_era5_ocean_99=ds['freq_list_era5_ocean'].values.tolist()[40:]
freq_list_era5_land_99=ds['freq_list_era5_land'].values.tolist()[40:]
intensity_list_era5_ocean_99=ds['intensity_list_era5_ocean'].values.tolist()[40:]
intensity_list_era5_land_99=ds['intensity_list_era5_land'].values.tolist()[40:]

# %%
ds=xr.open_dataset(dir_data+'hadex3_lines_r99p.nc')
starting_01_99=ds['starting_01'].values.tolist()
starting_40_99=ds['starting_40'].values.tolist()
starting_50_99=ds['starting_50'].values.tolist()
starting_79_99=ds['starting_79'].values.tolist()

ds=xr.open_dataset(dir_data+'hadex3_lines_r95p.nc')
starting_01_95=ds['starting_01'].values.tolist()
starting_40_95=ds['starting_40'].values.tolist()
starting_50_95=ds['starting_50'].values.tolist()
starting_79_95=ds['starting_79'].values.tolist()

ds=xr.open_dataset(dir_data+'hadex3_lines_total.nc')
starting_01_total=ds['starting_01'].values.tolist()
starting_40_total=ds['starting_40'].values.tolist()
starting_50_total=ds['starting_50'].values.tolist()
starting_79_total=ds['starting_79'].values.tolist()

# %%
list_1=[total_list_persiann_ocean_wet,total_list_persiann_land_wet,
      freq_list_persiann_ocean_wet,freq_list_persiann_land_wet,
      intensity_list_persiann_ocean_wet,intensity_list_persiann_land_wet,
      total_list_persiann_ocean_98,total_list_persiann_land_98,
      freq_list_persiann_ocean_98,freq_list_persiann_land_98,
      intensity_list_persiann_ocean_98,intensity_list_persiann_land_98,
      total_list_persiann_ocean_95,total_list_persiann_land_95,
      freq_list_persiann_ocean_95,freq_list_persiann_land_95,
      intensity_list_persiann_ocean_95,intensity_list_persiann_land_95,
      total_list_persiann_ocean_99,total_list_persiann_land_99,
      freq_list_persiann_ocean_99,freq_list_persiann_land_99,
      intensity_list_persiann_ocean_99,intensity_list_persiann_land_99]

list_2=[total_list_mswep_past_ocean_wet,total_list_mswep_past_land_wet,
      freq_list_mswep_past_ocean_wet,freq_list_mswep_past_land_wet,
      intensity_list_mswep_past_ocean_wet,intensity_list_mswep_past_land_wet,
      total_list_mswep_past_ocean_98,total_list_mswep_past_land_98,
      freq_list_mswep_past_ocean_98,freq_list_mswep_past_land_98,
      intensity_list_mswep_past_ocean_98,intensity_list_mswep_past_land_98,
      total_list_mswep_past_ocean_95,total_list_mswep_past_land_95,
      freq_list_mswep_past_ocean_95,freq_list_mswep_past_land_95,
      intensity_list_mswep_past_ocean_95,intensity_list_mswep_past_land_95,
      total_list_mswep_past_ocean_99,total_list_mswep_past_land_99,
      freq_list_mswep_past_ocean_99,freq_list_mswep_past_land_99,
      intensity_list_mswep_past_ocean_99,intensity_list_mswep_past_land_99]

list_3=[total_list_cpc_land_wet,freq_list_cpc_land_wet,
      intensity_list_cpc_land_wet,total_list_cpc_land_98,
      freq_list_cpc_land_98,intensity_list_cpc_land_98,
      total_list_cpc_land_95,freq_list_cpc_land_95,
      intensity_list_cpc_land_95,total_list_cpc_land_99,
      freq_list_cpc_land_99,intensity_list_cpc_land_99]

list_4=[total_list_regen_land_wet,freq_list_regen_land_wet,
      intensity_list_regen_land_wet,total_list_regen_land_98,
      freq_list_regen_land_98,intensity_list_regen_land_98,
      total_list_regen_land_95,freq_list_regen_land_95,
      intensity_list_regen_land_95,total_list_regen_land_99,
      freq_list_regen_land_99,intensity_list_regen_land_99]

list_5=[total_list_gpcc_land_wet,freq_list_gpcc_land_wet,
      intensity_list_gpcc_land_wet,total_list_gpcc_land_98,
      freq_list_gpcc_land_98,intensity_list_gpcc_land_98,
      total_list_gpcc_land_95,freq_list_gpcc_land_95,
      intensity_list_gpcc_land_95,total_list_gpcc_land_99,
      freq_list_gpcc_land_99,intensity_list_gpcc_land_99]

list_6=[starting_01_99,starting_40_99,starting_50_99,starting_79_99,
        starting_01_95,starting_40_95,starting_50_95,starting_79_95,
        starting_01_total,starting_40_total,starting_50_total,starting_79_total]

list_7=[total_list_imerg_ocean_wet,total_list_imerg_land_wet,
      freq_list_imerg_ocean_wet,freq_list_imerg_land_wet,
      intensity_list_imerg_ocean_wet,intensity_list_imerg_land_wet,
      total_list_imerg_ocean_98,total_list_imerg_land_98,
      freq_list_imerg_ocean_98,freq_list_imerg_land_98,
      intensity_list_imerg_ocean_98,intensity_list_imerg_land_98,
      total_list_imerg_ocean_95,total_list_imerg_land_95,
      freq_list_imerg_ocean_95,freq_list_imerg_land_95,
      intensity_list_imerg_ocean_95,intensity_list_imerg_land_95,
      total_list_imerg_ocean_99,total_list_imerg_land_99,
      freq_list_imerg_ocean_99,freq_list_imerg_land_99,
      intensity_list_imerg_ocean_99,intensity_list_imerg_land_99]

list_8=[total_list_gpcp_ocean_wet,total_list_gpcp_land_wet,
      freq_list_gpcp_ocean_wet,freq_list_gpcp_land_wet,
      intensity_list_gpcp_ocean_wet,intensity_list_gpcp_land_wet,
      total_list_gpcp_ocean_98,total_list_gpcp_land_98,
      freq_list_gpcp_ocean_98,freq_list_gpcp_land_98,
      intensity_list_gpcp_ocean_98,intensity_list_gpcp_land_98,
      total_list_gpcp_ocean_95,total_list_gpcp_land_95,
      freq_list_gpcp_ocean_95,freq_list_gpcp_land_95,
      intensity_list_gpcp_ocean_95,intensity_list_gpcp_land_95,
      total_list_gpcp_ocean_99,total_list_gpcp_land_99,
      freq_list_gpcp_ocean_99,freq_list_gpcp_land_99,
      intensity_list_gpcp_ocean_99,intensity_list_gpcp_land_99]

list_9=[total_list_gpcp3_ocean_wet,total_list_gpcp3_land_wet,
      freq_list_gpcp3_ocean_wet,freq_list_gpcp3_land_wet,
      intensity_list_gpcp3_ocean_wet,intensity_list_gpcp3_land_wet,
      total_list_gpcp3_ocean_98,total_list_gpcp3_land_98,
      freq_list_gpcp3_ocean_98,freq_list_gpcp3_land_98,
      intensity_list_gpcp3_ocean_98,intensity_list_gpcp3_land_98,
      total_list_gpcp3_ocean_95,total_list_gpcp3_land_95,
      freq_list_gpcp3_ocean_95,freq_list_gpcp3_land_95,
      intensity_list_gpcp3_ocean_95,intensity_list_gpcp3_land_95,
      total_list_gpcp3_ocean_99,total_list_gpcp3_land_99,
      freq_list_gpcp3_ocean_99,freq_list_gpcp3_land_99,
      intensity_list_gpcp3_ocean_99,intensity_list_gpcp3_land_99]

list_10=[total_list_era5_ocean_wet,total_list_era5_land_wet,
      freq_list_era5_ocean_wet,freq_list_era5_land_wet,
      intensity_list_era5_ocean_wet,intensity_list_era5_land_wet,
      total_list_era5_ocean_98,total_list_era5_land_98,
      freq_list_era5_ocean_98,freq_list_era5_land_98,
      intensity_list_era5_ocean_98,intensity_list_era5_land_98,
      total_list_era5_ocean_95,total_list_era5_land_95,
      freq_list_era5_ocean_95,freq_list_era5_land_95,
      intensity_list_era5_ocean_95,intensity_list_era5_land_95,
      total_list_era5_ocean_99,total_list_era5_land_99,
      freq_list_era5_ocean_99,freq_list_era5_land_99,
      intensity_list_era5_ocean_99,intensity_list_era5_land_99]

list_11=[total_list_merra2_ocean_wet,total_list_merra2_land_wet,
      freq_list_merra2_ocean_wet,freq_list_merra2_land_wet,
      intensity_list_merra2_ocean_wet,intensity_list_merra2_land_wet,
      total_list_merra2_ocean_98,total_list_merra2_land_98,
      freq_list_merra2_ocean_98,freq_list_merra2_land_98,
      intensity_list_merra2_ocean_98,intensity_list_merra2_land_98,
      total_list_merra2_ocean_95,total_list_merra2_land_95,
      freq_list_merra2_ocean_95,freq_list_merra2_land_95,
      intensity_list_merra2_ocean_95,intensity_list_merra2_land_95,
      total_list_merra2_ocean_99,total_list_merra2_land_99,
      freq_list_merra2_ocean_99,freq_list_merra2_land_99,
      intensity_list_merra2_ocean_99,intensity_list_merra2_land_99]

list_12=[total_list_jra55_ocean_wet,total_list_jra55_land_wet,
      freq_list_jra55_ocean_wet,freq_list_jra55_land_wet,
      intensity_list_jra55_ocean_wet,intensity_list_jra55_land_wet,
      total_list_jra55_ocean_98,total_list_jra55_land_98,
      freq_list_jra55_ocean_98,freq_list_jra55_land_98,
      intensity_list_jra55_ocean_98,intensity_list_jra55_land_98,
      total_list_jra55_ocean_95,total_list_jra55_land_95,
      freq_list_jra55_ocean_95,freq_list_jra55_land_95,
      intensity_list_jra55_ocean_95,intensity_list_jra55_land_95,
      total_list_jra55_ocean_99,total_list_jra55_land_99,
      freq_list_jra55_ocean_99,freq_list_jra55_land_99,
      intensity_list_jra55_ocean_99,intensity_list_jra55_land_99]

list_all=list_1+list_2+list_3+list_4+list_5+list_6+list_7+list_8+list_9+list_10+list_11+list_12
#list_all=list_1+list_2+list_3+list_4+list_5+list_10+list_11+list_12#medium- and long-term
print(len(list_all))

# %%
slopes_list=[]
sigs_list=[]
for i in range(len(list_all)):
    list_sel=list_all[i]
    print(len(list_sel))
    list_sel_defined=[x for x in list_sel if x>=0]
    list_mean=float(sum(list_sel_defined))/float(len(list_sel_defined))
    
    zipped_yrs=list(zip(np.arange(len(list_sel)),list_sel))
    select_yrs=[x[0] for x in zipped_yrs if x[1]>=0]
    select_values=[x[1] for x in zipped_yrs if x[1]>=0]
    
    r=st.linregress(select_yrs,select_values)
 2.7905919858443533e-07, 0.22353891328352, 0.36594430145488, 2.596039296779132e-10, 3.2999281991736237e-05, 0.0008323988824583634, 6.892787696209151e-09, 0.036197201283250754, 0.26207750596330104, 5.2303280259838026e-09, 0.10589512367459002, 7.48997948656916e-05, 0.0012194294533298905, 0.0009134035983148391, 0.0003573196901178043, 7.819152857740419e-09, 3.275659527165768e-24, 0.07365877623990061, 2.895713534126067e-09, 0.9778035285187141, 1.0732368246034183e-21, 4.203004430909989e-05, 0.05636761824795515, 0.7152158997526346, 0.17360055309382333, 0.03228564658806268, 7.686584131441462e-10, 2.9084616111097583e-10, 6.999550363666844e-10, 0.032291169888474365, 2.453094387870807e-10, 0.1692764274012329, 5.25761093729909e-06, 4.833371500599109e-09, 0.0003545103102588925, 0.8153692316674381, 2.2171120981870187e-05, 0.5328384950579927, 0.9280435054601637, 3.762699144137195e-10]
list_final=list_80+list_90+list_whole
print(len(list_final))

# %%
p_values=list_final#sigs_list
p_values=sorted([x for x in p_values if x>=0])
N=len(p_values)
a=0.05#/sum_factor
pass_list=[]
for i in range(len(p_values)):
    index=i+1
    p_value=p_values[i]
    if p_value<=a*index/float(N):
        pass_list.append(p_value)
p_final=max(pass_list)
print(p_final)

# %%
labels=['REGEN','GPCC V2022','CPC Unified','MSWEP V2.8','PERSIANN-\nCDR','MERRA-2','JRA-55','ERA5']#,'HadEX3 \n1940']
labels1=['R1mm','R98$\mathregular{p_{all}}$','R95p','R99p',
         'F1mm','F98$\mathregular{p_{all}}$','F95p','F99p',
         'I1mm','I98$\mathregular{p_{all}}$','I95p','I99p']

fig=plt.figure(figsize=(16,8))
ax=plt.subplot(1,1,1)
ax.axis('off')
#ax.axis('tight')

cell_text=np.zeros((12,8))
sigs_text=np.zeros((12,8))
#cell_text=np.chararray((12,9))

######
list_sel=[total_list_regen_land_wet,total_list_regen_land_98,total_list_regen_land_95,total_list_regen_land_99,
          freq_list_regen_land_wet,freq_list_regen_land_98,freq_list_regen_land_95,freq_list_regen_land_99,
          intensity_list_regen_land_wet,intensity_list_regen_land_98,intensity_list_regen_land_95,
          intensity_list_regen_land_99]
for i in range(len(list_sel)):
    list_sel1=list_sel[i]
    list_sel_defined=[x for x in list_sel1 if x>=0]
    list_mean=float(sum(list_sel_defined))/float(len(list_sel_defined))
    
    zipped_yrs=list(zip(np.arange(len(list_sel1)),list_sel1))
    select_yrs=[x[0] for x in zipped_yrs if x[1]>=0]
    select_values=[x[1] for x in zipped_yrs if x[1]>=0]
    
    r=st.linregress(select_yrs,select_values)
    slope=r[0]/list_mean*100.#percent slope
    sig=r[3]
    
    cell_text[i,0]=str(round(slope,2))
    sigs_text[i,0]=sig
    
######  

list_sel=[total_list_gpcc_land_wet,total_list_gpcc_land_98,total_list_gpcc_land_95,total_list_gpcc_land_99,
          freq_list_gpcc_land_wet,freq_list_gpcc_land_98,freq_list_gpcc_land_95,freq_list_gpcc_land_99,
          intensity_list_gpcc_land_wet,intensity_list_gpcc_land_98,intensity_list_gpcc_land_95,
          intensity_list_gpcc_land_99]

for i in range(len(list_sel)):
    list_sel1=list_sel[i]
    list_sel_defined=[x for x in list_sel1 if x>=0]
    list_mean=float(sum(list_sel_defined))/float(len(list_sel_defined))
    
    zipped_yrs=list(zip(np.arange(len(list_sel1)),list_sel1))
    select_yrs=[x[0] for x in zipped_yrs if x[1]>=0]
    select_values=[x[1] for x in zipped_yrs if x[1]>=0]
    
    r=st.linregress(select_yrs,select_values)
    slope=r[0]/list_mean*100.#percent slope
    sig=r[3]
    
    cell_text[i,1]=str(round(slope,2))
    sigs_text[i,1]=sig
    
#######

list_sel=[total_list_cpc_land_wet,total_list_cpc_land_98,total_list_cpc_land_95,total_list_cpc_land_99,
          freq_list_cpc_land_wet,freq_list_cpc_land_98,freq_list_cpc_land_95,freq_list_cpc_land_99,
          intensity_list_cpc_land_wet,intensity_list_cpc_land_98,intensity_list_cpc_land_95,
          intensity_list_cpc_land_99]

for i in range(len(list_sel)):
    list_sel1=list_sel[i]
    list_sel_defined=[x for x in list_sel1 if x>=0]
    list_mean=float(sum(list_sel_defined))/float(len(list_sel_defined))
    
    zipped_yrs=list(zip(np.arange(len(list_sel1)),list_sel1))
    select_yrs=[x[0] for x in zipped_yrs if x[1]>=0]
    select_values=[x[1] for x in zipped_yrs if x[1]>=0]
    
    r=st.linregress(select_yrs,select_values)
    slope=r[0]/list_mean*100.#percent slope
    sig=r[3]
    
    cell_text[i,2]=str(round(slope,2))
    sigs_text[i,2]=sig
    
########

list_sel=[total_list_mswep_past_land_wet,total_list_mswep_past_land_98,total_list_mswep_past_land_95,total_list_mswep_past_land_99,
          freq_list_mswep_past_land_wet,freq_list_mswep_past_land_98,freq_list_mswep_past_land_95,freq_list_mswep_past_land_99,
          intensity_list_mswep_past_land_wet,intensity_list_mswep_past_land_98,intensity_list_mswep_past_land_95,
          intensity_list_mswep_past_land_99]

for i in range(len(list_sel)):
    list_sel1=list_sel[i]
    list_sel_defined=[x for x in list_sel1 if x>=0]
    list_mean=float(sum(list_sel_defined))/float(len(list_sel_defined))
    
    zipped_yrs=list(zip(np.arange(len(list_sel1)),list_sel1))
    select_yrs=[x[0] for x in zipped_yrs if x[1]>=0]
    select_values=[x[1] for x in zipped_yrs if x[1]>=0]
    
    r=st.linregress(select_yrs,select_values)
    slope=r[0]/list_mean*100.#percent slope
    sig=r[3]
    
    cell_text[i,3]=str(round(slope,2))
    sigs_text[i,3]=sig
    
########

list_sel=[total_list_persiann_land_wet,total_list_persiann_land_98,total_list_persiann_land_95,total_list_persiann_land_99,
          freq_list_persiann_land_wet,freq_list_persiann_land_98,freq_list_persiann_land_95,freq_list_persiann_land_99,
          intensity_list_persiann_land_wet,intensity_list_persiann_land_98,intensity_list_persiann_land_95,
          intensity_list_persiann_land_99]

for i in range(len(list_sel)):
    list_sel1=list_sel[i]
    list_sel_defined=[x for x in list_sel1 if x>=0]
    list_mean=float(sum(list_sel_defined))/float(len(list_sel_defined))
    
    zipped_yrs=list(zip(np.arange(len(list_sel1)),list_sel1))
    select_yrs=[x[0] for x in zipped_yrs if x[1]>=0]
    select_values=[x[1] for x in zipped_yrs if x[1]>=0]
    
    r=st.linregress(select_yrs,select_values)
    slope=r[0]/list_mean*100.#percent slope
    sig=r[3]
    
    cell_text[i,4]=str(round(slope,2))
    sigs_text[i,4]=sig
    
#########

list_sel=[total_list_merra2_land_wet,total_list_merra2_land_98,total_list_merra2_land_95,total_list_merra2_land_99,
          freq_list_merra2_land_wet,freq_list_merra2_land_98,freq_list_merra2_land_95,freq_list_merra2_land_99,
          intensity_list_merra2_land_wet,intensity_list_merra2_land_98,intensity_list_merra2_land_95,
          intensity_list_merra2_land_99]

for i in range(len(list_sel)):
    list_sel1=list_sel[i]
    list_sel_defined=[x for x in list_sel1 if x>=0]
    list_mean=float(sum(list_sel_defined))/float(len(list_sel_defined))
    
    zipped_yrs=list(zip(np.arange(len(list_sel1)),list_sel1))
    select_yrs=[x[0] for x in zipped_yrs if x[1]>=0]
    select_values=[x[1] for x in zipped_yrs if x[1]>=0]
    
    r=st.linregress(select_yrs,select_values)
    slope=r[0]/list_mean*100.#percent slope
    sig=r[3]
    
    cell_text[i,5]=str(round(slope,2))
    sigs_text[i,5]=sig
    
#########

list_sel=[total_list_jra55_land_wet,total_list_jra55_land_98,total_list_jra55_land_95,total_list_jra55_land_99,
          freq_list_jra55_land_wet,freq_list_jra55_land_98,freq_list_jra55_land_95,freq_list_jra55_land_99,
          intensity_list_jra55_land_wet,intensity_list_jra55_land_98,intensity_list_jra55_land_95,
          intensity_list_jra55_land_99]

for i in range(len(list_sel)):
    list_sel1=list_sel[i]
    list_sel_defined=[x for x in list_sel1 if x>=0]
    list_mean=float(sum(list_sel_defined))/float(len(list_sel_defined))
    
    zipped_yrs=list(zip(np.arange(len(list_sel1)),list_sel1))
    select_yrs=[x[0] for x in zipped_yrs if x[1]>=0]
    select_values=[x[1] for x in zipped_yrs if x[1]>=0]
    
    r=st.linregress(select_yrs,select_values)
    slope=r[0]/list_mean*100.#percent slope
    sig=r[3]
    
    cell_text[i,6]=str(round(slope,2))
    sigs_text[i,6]=sig
    
########

list_sel=[total_list_era5_land_wet,total_list_era5_land_98,total_list_era5_land_95,total_list_era5_land_99,
          freq_list_era5_land_wet,freq_list_era5_land_98,freq_list_era5_land_95,freq_list_era5_land_99,
          intensity_list_era5_land_wet,intensity_list_era5_land_98,intensity_list_era5_land_95,
          intensity_list_era5_land_99]

for i in range(len(list_sel)):
    list_sel1=list_sel[i]
    list_sel_defined=[x for x in list_sel1 if x>=0]
    list_mean=float(sum(list_sel_defined))/float(len(list_sel_defined))
    
    zipped_yrs=list(zip(np.arange(len(list_sel1)),list_sel1))
    select_yrs=[x[0] for x in zipped_yrs if x[1]>=0]
    select_values=[x[1] for x in zipped_yrs if x[1]>=0]
    
    r=st.linregress(select_yrs,select_values)
    slope=r[0]/list_mean*100.#percent slope
    sig=r[3]
    
    cell_text[i,7]=str(round(slope,2))
    sigs_text[i,7]=sig
     
if 1==0:
    list_sel=[starting_40_total,starting_40_95,starting_40_99]
    for i in range(len(list_sel)):
        list_sel1=list_sel[i]
        list_sel_defined=[x for x in list_sel1 if x>=0]
        list_mean=float(sum(list_sel_defined))/float(len(list_sel_defined))

        zipped_yrs=list(zip(np.arange(len(list_sel1)),list_sel1))
        select_yrs=[x[0] for x in zipped_yrs if x[1]>=0]
        select_values=[x[1] for x in zipped_yrs if x[1]>=0]

        r=st.linregress(select_yrs,select_values)
        slope=r[0]/list_mean*100.#percent slope
        sig=r[3]

        if i==0:
            cell_text[i,8]=str(round(slope,2))
            sigs_text[i,8]=sig
        if i==1:
            cell_text[2,8]=str(round(slope,2))
            sigs_text[2,8]=sig
        if i==2:
            cell_text[3,8]=str(round(slope,2))
            sigs_text[3,8]=sig
        
table=ax.table(cellText=cell_text,rowLabels=labels1,colLabels=labels,
               colWidths=[0.1]*8,loc='center')
table.auto_set_font_size(False)
table.set_fontsize(29)
table.scale(2.2,6)


from matplotlib.colors import LinearSegmentedColormap
cmap1=LinearSegmentedColormap.from_list('cmap1',['darkorange','r','darkred'])
cmap1=cmap1(np.linspace(0,1,101))

cmap2=LinearSegmentedColormap.from_list('cmap2',['dodgerblue','b','darkblue'])
cmap2=cmap2(np.linspace(0,1,101))

from matplotlib.font_manager import FontProperties
for (row, col), cell in table.get_celld().items():
    #if (row == 0) or (col == -1):
    #if col==-1:
    if 1==0:
        cell.set_text_props(fontproperties=FontProperties(weight='bold',size=29))

    if row>=1 and col>=0:
        if sigs_text[row-1,col]<=p_final:
            cell.set_text_props(fontproperties=FontProperties(weight='bold',size=29))
            if cell_text[row-1,col]>0:
                
                index=int(min(cell_text[row-1,col]*100.,100))
                color_choose=cmap1[index]
                cell.set_text_props(color=color_choose)
                
            if cell_text[row-1,col]<0:
                
                index=int(min(abs(cell_text[row-1,col])*100.,100))
                color_choose=cmap2[index]
                cell.set_text_props(color=color_choose)
                
        if col==8 and row not in [1,3,4]:
            table._cells[(row,col)]._text.set_text(' ')


ax.set_title(r'$\bf{60S-70N}$'+' '+r'$\bf{land}$'+' '+r'$\bf{precipitation}$'+' '+r'$\bf{trends, }$'+r'$\bf{1980-end}$',fontsize=42,pad=270)
plt.show()
#plt.tight_layout()

# %%
fig.savefig(dir_data+'table_1_80.png')

# %%
labels=['MSWEP V2.8','PERSIANN-\nCDR','MERRA-2','JRA-55','ERA5']
labels1=['R1mm','R98$\mathregular{p_{all}}$','R95p','R99p',
         'F1mm','F98$\mathregular{p_{all}}$','F95p','F99p',
         'I1mm','I98$\mathregular{p_{all}}$','I95p','I99p']

fig=plt.figure(figsize=(16,8))
ax=plt.subplot(1,1,1)
ax.axis('off')
#ax.axis('tight')

cell_text=np.zeros((12,5))
sigs_text=np.zeros((12,5))
#cell_text=np.chararray((12,9))


    
########

list_sel=[total_list_mswep_past_ocean_wet,total_list_mswep_past_ocean_98,total_list_mswep_past_ocean_95,total_list_mswep_past_ocean_99,
          freq_list_mswep_past_ocean_wet,freq_list_mswep_past_ocean_98,freq_list_mswep_past_ocean_95,freq_list_mswep_past_ocean_99,
          intensity_list_mswep_past_ocean_wet,intensity_list_mswep_past_ocean_98,intensity_list_mswep_past_ocean_95,
          intensity_list_mswep_past_ocean_99]

for i in range(len(list_sel)):
    list_sel1=list_sel[i]
    list_sel_defined=[x for x in list_sel1 if x>=0]
    list_mean=float(sum(list_sel_defined))/float(len(list_sel_defined))
    
    zipped_yrs=list(zip(np.arange(len(list_sel1)),list_sel1))
    select_yrs=[x[0] for x in zipped_yrs if x[1]>=0]
    select_values=[x[1] for x in zipped_yrs if x[1]>=0]
    
    r=st.linregress(select_yrs,select_values)
    slope=r[0]/list_mean*100.#percent slope
    sig=r[3]
    
    cell_text[i,0]=str(round(slope,2))
    sigs_text[i,0]=sig
    
########

list_sel=[total_list_persiann_ocean_wet,total_list_persiann_ocean_98,total_list_persiann_ocean_95,total_list_persiann_ocean_99,
          freq_list_persiann_ocean_wet,freq_list_persiann_ocean_98,freq_list_persiann_ocean_95,freq_list_persiann_ocean_99,
          intensity_list_persiann_ocean_wet,intensity_list_persiann_ocean_98,intensity_list_persiann_ocean_95,
          intensity_list_persiann_ocean_99]

for i in range(len(list_sel)):
    list_sel1=list_sel[i]
    list_sel_defined=[x for x in list_sel1 if x>=0]
    list_mean=float(sum(list_sel_defined))/float(len(list_sel_defined))
    
    zipped_yrs=list(zip(np.arange(len(list_sel1)),list_sel1))
    select_yrs=[x[0] for x in zipped_yrs if x[1]>=0]
    select_values=[x[1] for x in zipped_yrs if x[1]>=0]
    
    r=st.linregress(select_yrs,select_values)
    slope=r[0]/list_mean*100.#percent slope
    sig=r[3]
    
    cell_text[i,1]=str(round(slope,2))
    sigs_text[i,1]=sig
    
#########

list_sel=[total_list_merra2_ocean_wet,total_list_merra2_ocean_98,total_list_merra2_ocean_95,total_list_merra2_ocean_99,
          freq_list_merra2_ocean_wet,freq_list_merra2_ocean_98,freq_list_merra2_ocean_95,freq_list_merra2_ocean_99,
          intensity_list_merra2_ocean_wet,intensity_list_merra2_ocean_98,intensity_list_merra2_ocean_95,
          intensity_list_merra2_ocean_99]

for i in range(len(list_sel)):
    list_sel1=list_sel[i]
    list_sel_defined=[x for x in list_sel1 if x>=0]
    list_mean=float(sum(list_sel_defined))/float(len(list_sel_defined))
    
    zipped_yrs=list(zip(np.arange(len(list_sel1)),list_sel1))
    select_yrs=[x[0] for x in zipped_yrs if x[1]>=0]
    select_values=[x[1] for x in zipped_yrs if x[1]>=0]
    
    r=st.linregress(select_yrs,select_values)
    slope=r[0]/list_mean*100.#percent slope
    sig=r[3]
    
    cell_text[i,2]=str(round(slope,2))
    sigs_text[i,2]=sig
    
#########

list_sel=[total_list_jra55_ocean_wet,total_list_jra55_ocean_98,total_list_jra55_ocean_95,total_list_jra55_ocean_99,
          freq_list_jra55_ocean_wet,freq_list_jra55_ocean_98,freq_list_jra55_ocean_95,freq_list_jra55_ocean_99,
          intensity_list_jra55_ocean_wet,intensity_list_jra55_ocean_98,intensity_list_jra55_ocean_95,
          intensity_list_jra55_ocean_99]

for i in range(len(list_sel)):
    list_sel1=list_sel[i]
    list_sel_defined=[x for x in list_sel1 if x>=0]
    list_mean=float(sum(list_sel_defined))/float(len(list_sel_defined))
    
    zipped_yrs=list(zip(np.arange(len(list_sel1)),list_sel1))
    select_yrs=[x[0] for x in zipped_yrs if x[1]>=0]
    select_values=[x[1] for x in zipped_yrs if x[1]>=0]
    
    r=st.linregress(select_yrs,select_values)
    slope=r[0]/list_mean*100.#percent slope
    sig=r[3]
    
    cell_text[i,3]=str(round(slope,2))
    sigs_text[i,3]=sig
    
########

list_sel=[total_list_era5_ocean_wet,total_list_era5_ocean_98,total_list_era5_ocean_95,total_list_era5_ocean_99,
          freq_list_era5_ocean_wet,freq_list_era5_ocean_98,freq_list_era5_ocean_95,freq_list_era5_ocean_99,
          intensity_list_era5_ocean_wet,intensity_list_era5_ocean_98,intensity_list_era5_ocean_95,
          intensity_list_era5_ocean_99]

for i in range(len(list_sel)):
    list_sel1=list_sel[i]
    list_sel_defined=[x for x in list_sel1 if x>=0]
    list_mean=float(sum(list_sel_defined))/float(len(list_sel_defined))
    
    zipped_yrs=list(zip(np.arange(len(list_sel1)),list_sel1))
    select_yrs=[x[0] for x in zipped_yrs if x[1]>=0]
    select_values=[x[1] for x in zipped_yrs if x[1]>=0]
    
    r=st.linregress(select_yrs,select_values)
    slope=r[0]/list_mean*100.#percent slope
    sig=r[3]
    
    cell_text[i,4]=str(round(slope,2))
    sigs_text[i,4]=sig
        
        
table=ax.table(cellText=cell_text,rowLabels=labels1,colLabels=labels,
               colWidths=[0.1]*5,loc='center')
table.auto_set_font_size(False)
table.set_fontsize(29)
table.scale(2.2,6)


from matplotlib.colors import LinearSegmentedColormap
cmap1=LinearSegmentedColormap.from_list('cmap1',['darkorange','r','darkred'])
cmap1=cmap1(np.linspace(0,1,101))

cmap2=LinearSegmentedColormap.from_list('cmap2',['dodgerblue','b','darkblue'])
cmap2=cmap2(np.linspace(0,1,101))

from matplotlib.font_manager import FontProperties
for (row, col), cell in table.get_celld().items():
    #if (row == 0) or (col == -1):
    #if col==-1:
    if 1==0:
        cell.set_text_props(fontproperties=FontProperties(weight='bold',size=29))

    if row>=1 and col>=0:
        if sigs_text[row-1,col]<=p_final:
            cell.set_text_props(fontproperties=FontProperties(weight='bold',size=29))
            if cell_text[row-1,col]>0:
                
                index=int(min(cell_text[row-1,col]*100.,100))
                color_choose=cmap1[index]
                cell.set_text_props(color=color_choose)
                
            if cell_text[row-1,col]<0:
                
                index=int(min(abs(cell_text[row-1,col])*100.,100))
                color_choose=cmap2[index]
                cell.set_text_props(color=color_choose)


ax.set_title(r'$\bf{60S-70N}$'+' '+r'$\bf{ocean}$'+' '+r'$\bf{precipitation}$'+' '+r'$\bf{trends, }$'+r'$\bf{1980-end}$',fontsize=38,pad=270)
plt.show()
#plt.tight_layout()

# %%
fig.savefig(dir_data+'table_2_80.png')
