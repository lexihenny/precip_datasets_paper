# %%
import numpy as np
import xarray as xr
import scipy.stats as st
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import requests
import os,errno
import sys
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER,LATITUDE_FORMATTER
import matplotlib.ticker as mticker
import cartopy.feature as cfeature
import datetime as dt
import pandas as pd
import time
import urllib.request
import metpy.calc as mpcalc
import salem
import scipy.optimize as opt
import warnings
import geopy.distance
import matplotlib as mpl
import matplotlib.colors as mcolors
from matplotlib.lines import Line2D
import matplotlib.backends.backend_pdf

from scipy.ndimage.measurements import label
from scipy.ndimage import binary_dilation

warnings.filterwarnings('ignore')

# %matplotlib inline

dir_data='/Users/ahenny/'
dir1='/Volumes/LaCie/'
dir2='/Volumes/Extreme Pro/'
dir3='/Volumes/My Passport/day/'

# %%
ds=xr.open_dataset(dir_data+'precip_datasets_compare_persiann_wet_6070_test.nc')
total_list_persiann_ocean_wet=ds['total_list_persiann_ocean'].values.tolist()
total_list_persiann_land_wet=ds['total_list_persiann_land'].values.tolist()
total_persiann_ocean_monthly_wet=ds['total_persiann_ocean_monthly'].values
total_persiann_land_monthly_wet=ds['total_persiann_land_monthly'].values

ds=xr.open_dataset(dir_data+'precip_datasets_compare_persiann_x_6070_test.nc')
total_list_persiann_ocean_98=ds['total_list_persiann_ocean'].values.tolist()
total_list_persiann_land_98=ds['total_list_persiann_land'].values.tolist()
total_persiann_ocean_monthly_98=ds['total_persiann_ocean_monthly'].values
total_persiann_land_monthly_98=ds['total_persiann_land_monthly'].values

ds=xr.open_dataset(dir_data+'precip_datasets_compare_persiann_r95p_6070_test.nc')
total_list_persiann_ocean_95=ds['total_list_persiann_ocean'].values.tolist()
total_list_persiann_land_95=ds['total_list_persiann_land'].values.tolist()
total_persiann_ocean_monthly_95=ds['total_persiann_ocean_monthly'].values
total_persiann_land_monthly_95=ds['total_persiann_land_monthly'].values

ds=xr.open_dataset(dir_data+'precip_datasets_compare_persiann_r99p_6070_test.nc')
total_list_persiann_ocean_99=ds['total_list_persiann_ocean'].values.tolist()
total_list_persiann_land_99=ds['total_list_persiann_land'].values.tolist()
total_persiann_ocean_monthly_99=ds['total_persiann_ocean_monthly'].values
total_persiann_land_monthly_99=ds['total_persiann_land_monthly'].values

# %%
ds=xr.open_dataset(dir_data+'precip_datasets_compare_mswep_past_wet_6070_test.nc')
total_list_mswep_past_ocean_wet=ds['total_list_mswep_past_ocean'].values.tolist()
total_list_mswep_past_land_wet=ds['total_list_mswep_past_land'].values.tolist()
total_mswep_past_ocean_monthly_wet=ds['total_mswep_past_ocean_monthly'].values
total_mswep_past_land_monthly_wet=ds['total_mswep_past_land_monthly'].values

ds=xr.open_dataset(dir_data+'precip_datasets_compare_mswep_past_x_6070_test.nc')
total_list_mswep_past_ocean_98=ds['total_list_mswep_past_ocean'].values.tolist()
total_list_mswep_past_land_98=ds['total_list_mswep_past_land'].values.tolist()
total_mswep_past_ocean_monthly_98=ds['total_mswep_past_ocean_monthly'].values
total_mswep_past_land_monthly_98=ds['total_mswep_past_land_monthly'].values

ds=xr.open_dataset(dir_data+'precip_datasets_compare_mswep_past_r95p_6070_test.nc')
total_list_mswep_past_ocean_95=ds['total_list_mswep_past_ocean'].values.tolist()
total_list_mswep_past_land_95=ds['total_list_mswep_past_land'].values.tolist()
total_mswep_past_ocean_monthly_95=ds['total_mswep_past_ocean_monthly'].values
total_mswep_past_land_monthly_95=ds['total_mswep_past_land_monthly'].values

ds=xr.open_dataset(dir_data+'precip_datasets_compare_mswep_past_r99p_6070_test.nc')
total_list_mswep_past_ocean_99=ds['total_list_mswep_past_ocean'].values.tolist()
total_list_mswep_past_land_99=ds['total_list_mswep_past_land'].values.tolist()
total_mswep_past_ocean_monthly_99=ds['total_mswep_past_ocean_monthly'].values
total_mswep_past_land_monthly_99=ds['total_mswep_past_land_monthly'].values

# %%
ds=xr.open_dataset(dir_data+'precip_datasets_compare_cpc_wet_6070_test.nc')
total_list_cpc_land_wet=ds['total_list_cpc_land'].values.tolist()
total_cpc_land_monthly_wet=ds['total_cpc_land_monthly'].values

ds=xr.open_dataset(dir_data+'precip_datasets_compare_cpc_x_6070_test.nc')
total_list_cpc_land_98=ds['total_list_cpc_land'].values.tolist()
total_cpc_land_monthly_98=ds['total_cpc_land_monthly'].values

ds=xr.open_dataset(dir_data+'precip_datasets_compare_cpc_r95p_6070_test.nc')
total_list_cpc_land_95=ds['total_list_cpc_land'].values.tolist()
total_cpc_land_monthly_95=ds['total_cpc_land_monthly'].values

ds=xr.open_dataset(dir_data+'precip_datasets_compare_cpc_r99p_6070_test.nc')
total_list_cpc_land_99=ds['total_list_cpc_land'].values.tolist()
total_cpc_land_monthly_99=ds['total_cpc_land_monthly'].values

# %%
ds=xr.open_dataset(dir_data+'precip_datasets_compare_gpcc_wet_6070_test.nc')
total_list_gpcc_land_wet=ds['total_list_gpcc_land'].values.tolist()
total_gpcc_land_monthly_wet=ds['total_gpcc_land_monthly'].values

ds=xr.open_dataset(dir_data+'precip_datasets_compare_gpcc_x_6070_test.nc')
total_list_gpcc_land_98=ds['total_list_gpcc_land'].values.tolist()
total_gpcc_land_monthly_98=ds['total_gpcc_land_monthly'].values

ds=xr.open_dataset(dir_data+'precip_datasets_compare_gpcc_r95p_6070_test.nc')
total_list_gpcc_land_95=ds['total_list_gpcc_land'].values.tolist()
total_gpcc_land_monthly_95=ds['total_gpcc_land_monthly'].values

ds=xr.open_dataset(dir_data+'precip_datasets_compare_gpcc_r99p_6070_test.nc')
total_list_gpcc_land_99=ds['total_list_gpcc_land'].values.tolist()
total_gpcc_land_monthly_99=ds['total_gpcc_land_monthly'].values

# %%
ds=xr.open_dataset(dir_data+'precip_datasets_compare_gpcp_wet_6070_test.nc')
total_list_gpcp_ocean_wet=ds['total_list_gpcp_ocean'].values.tolist()
total_list_gpcp_land_wet=ds['total_list_gpcp_land'].values.tolist()
total_gpcp_ocean_monthly_wet=ds['total_gpcp_ocean_monthly'].values
total_gpcp_land_monthly_wet=ds['total_gpcp_land_monthly'].values

ds=xr.open_dataset(dir_data+'precip_datasets_compare_gpcp_x_6070_test.nc')
total_list_gpcp_ocean_98=ds['total_list_gpcp_ocean'].values.tolist()
total_list_gpcp_land_98=ds['total_list_gpcp_land'].values.tolist()
total_gpcp_ocean_monthly_98=ds['total_gpcp_ocean_monthly'].values
total_gpcp_land_monthly_98=ds['total_gpcp_land_monthly'].values

ds=xr.open_dataset(dir_data+'precip_datasets_compare_gpcp_r95p_6070_test.nc')
total_list_gpcp_ocean_95=ds['total_list_gpcp_ocean'].values.tolist()
total_list_gpcp_land_95=ds['total_list_gpcp_land'].values.tolist()
total_gpcp_ocean_monthly_95=ds['total_gpcp_ocean_monthly'].values
total_gpcp_land_monthly_95=ds['total_gpcp_land_monthly'].values

ds=xr.open_dataset(dir_data+'precip_datasets_compare_gpcp_r99p_6070_test.nc')
total_list_gpcp_ocean_99=ds['total_list_gpcp_ocean'].values.tolist()
total_list_gpcp_land_99=ds['total_list_gpcp_land'].values.tolist()
total_gpcp_ocean_monthly_99=ds['total_gpcp_ocean_monthly'].values
total_gpcp_land_monthly_99=ds['total_gpcp_land_monthly'].values

# %%
ds=xr.open_dataset(dir_data+'precip_datasets_compare_gpcp3_wet_6070_test.nc')
total_list_gpcp3_ocean_wet=ds['total_list_gpcp3_ocean'].values.tolist()
total_list_gpcp3_land_wet=ds['total_list_gpcp3_land'].values.tolist()
total_gpcp3_ocean_monthly_wet=ds['total_gpcp3_ocean_monthly'].values
total_gpcp3_land_monthly_wet=ds['total_gpcp3_land_monthly'].values

ds=xr.open_dataset(dir_data+'precip_datasets_compare_gpcp3_x_6070_test.nc')
total_list_gpcp3_ocean_98=ds['total_list_gpcp3_ocean'].values.tolist()
total_list_gpcp3_land_98=ds['total_list_gpcp3_land'].values.tolist()
total_gpcp3_ocean_monthly_98=ds['total_gpcp3_ocean_monthly'].values
total_gpcp3_land_monthly_98=ds['total_gpcp3_land_monthly'].values

ds=xr.open_dataset(dir_data+'precip_datasets_compare_gpcp3_r95p_6070_test.nc')
total_list_gpcp3_ocean_95=ds['total_list_gpcp3_ocean'].values.tolist()
total_list_gpcp3_land_95=ds['total_list_gpcp3_land'].values.tolist()
total_gpcp3_ocean_monthly_95=ds['total_gpcp3_ocean_monthly'].values
total_gpcp3_land_monthly_95=ds['total_gpcp3_land_monthly'].values

ds=xr.open_dataset(dir_data+'precip_datasets_compare_gpcp3_r99p_6070_test.nc')
total_list_gpcp3_ocean_99=ds['total_list_gpcp3_ocean'].values.tolist()
total_list_gpcp3_land_99=ds['total_list_gpcp3_land'].values.tolist()
total_gpcp3_ocean_monthly_99=ds['total_gpcp3_ocean_monthly'].values
total_gpcp3_land_monthly_99=ds['total_gpcp3_land_monthly'].values

# %%
ds=xr.open_dataset(dir_data+'precip_datasets_compare_imerg_wet_6070_test.nc')
total_list_imerg_ocean_wet=ds['total_list_imerg_ocean'].values.tolist()
total_list_imerg_land_wet=ds['total_list_imerg_land'].values.tolist()
total_imerg_ocean_monthly_wet=ds['total_imerg_ocean_monthly'].values
total_imerg_land_monthly_wet=ds['total_imerg_land_monthly'].values

ds=xr.open_dataset(dir_data+'precip_datasets_compare_imerg_x_6070_test.nc')
total_list_imerg_ocean_98=ds['total_list_imerg_ocean'].values.tolist()
total_list_imerg_land_98=ds['total_list_imerg_land'].values.tolist()
total_imerg_ocean_monthly_98=ds['total_imerg_ocean_monthly'].values
total_imerg_land_monthly_98=ds['total_imerg_land_monthly'].values

ds=xr.open_dataset(dir_data+'precip_datasets_compare_imerg_r95p_6070_test.nc')
total_list_imerg_ocean_95=ds['total_list_imerg_ocean'].values.tolist()
total_list_imerg_land_95=ds['total_list_imerg_land'].values.tolist()
total_imerg_ocean_monthly_95=ds['total_imerg_ocean_monthly'].values
total_imerg_land_monthly_95=ds['total_imerg_land_monthly'].values

ds=xr.open_dataset(dir_data+'precip_datasets_compare_imerg_r99p_6070_test.nc')
total_list_imerg_ocean_99=ds['total_list_imerg_ocean'].values.tolist()
total_list_imerg_land_99=ds['total_list_imerg_land'].values.tolist()
total_imerg_ocean_monthly_99=ds['total_imerg_ocean_monthly'].values
total_imerg_land_monthly_99=ds['total_imerg_land_monthly'].values

# %%
ds=xr.open_dataset(dir_data+'precip_datasets_compare_merra2_wet_6070_test.nc')
total_list_merra2_ocean_wet=ds['total_list_merra2_ocean'].values.tolist()
total_list_merra2_land_wet=ds['total_list_merra2_land'].values.tolist()
total_merra2_ocean_monthly_wet=ds['total_merra2_ocean_monthly'].values
total_merra2_land_monthly_wet=ds['total_merra2_land_monthly'].values

ds=xr.open_dataset(dir_data+'precip_datasets_compare_merra2_x_6070_test.nc')
total_list_merra2_ocean_98=ds['total_list_merra2_ocean'].values.tolist()
total_list_merra2_land_98=ds['total_list_merra2_land'].values.tolist()
total_merra2_ocean_monthly_98=ds['total_merra2_ocean_monthly'].values
total_merra2_land_monthly_98=ds['total_merra2_land_monthly'].values

ds=xr.open_dataset(dir_data+'precip_datasets_compare_merra2_r95p_6070_test.nc')
total_list_merra2_ocean_95=ds['total_list_merra2_ocean'].values.tolist()
total_list_merra2_land_95=ds['total_list_merra2_land'].values.tolist()
total_merra2_ocean_monthly_95=ds['total_merra2_ocean_monthly'].values
total_merra2_land_monthly_95=ds['total_merra2_land_monthly'].values

ds=xr.open_dataset(dir_data+'precip_datasets_compare_merra2_r99p_6070_test.nc')
total_list_merra2_ocean_99=ds['total_list_merra2_ocean'].values.tolist()
total_list_merra2_land_99=ds['total_list_merra2_land'].values.tolist()
total_merra2_ocean_monthly_99=ds['total_merra2_ocean_monthly'].values
total_merra2_land_monthly_99=ds['total_merra2_land_monthly'].values

# %%
ds=xr.open_dataset(dir_data+'precip_datasets_compare_jra55_wet_6070_test.nc')
total_list_jra55_ocean_wet=ds['total_list_jra55_ocean'].values.tolist()
total_list_jra55_land_wet=ds['total_list_jra55_land'].values.tolist()
total_jra55_ocean_monthly_wet=ds['total_jra55_ocean_monthly'].values
total_jra55_land_monthly_wet=ds['total_jra55_land_monthly'].values

ds=xr.open_dataset(dir_data+'precip_datasets_compare_jra55_x_6070_test.nc')
total_list_jra55_ocean_98=ds['total_list_jra55_ocean'].values.tolist()
total_list_jra55_land_98=ds['total_list_jra55_land'].values.tolist()
total_jra55_ocean_monthly_98=ds['total_jra55_ocean_monthly'].values
total_jra55_land_monthly_98=ds['total_jra55_land_monthly'].values

ds=xr.open_dataset(dir_data+'precip_datasets_compare_jra55_r95p_6070_test.nc')
total_list_jra55_ocean_95=ds['total_list_jra55_ocean'].values.tolist()
total_list_jra55_land_95=ds['total_list_jra55_land'].values.tolist()
total_jra55_ocean_monthly_95=ds['total_jra55_ocean_monthly'].values
total_jra55_land_monthly_95=ds['total_jra55_land_monthly'].values

ds=xr.open_dataset(dir_data+'precip_datasets_compare_jra55_r99p_6070_test.nc')
total_list_jra55_ocean_99=ds['total_list_jra55_ocean'].values.tolist()
total_list_jra55_land_99=ds['total_list_jra55_land'].values.tolist()
total_jra55_ocean_monthly_99=ds['total_jra55_ocean_monthly'].values
total_jra55_land_monthly_99=ds['total_jra55_land_monthly'].values

# %%
ds=xr.open_dataset(dir_data+'precip_datasets_compare_era5_wet_6070_test.nc')
total_list_era5_ocean_wet=ds['total_list_era5_ocean'].values.tolist()
total_list_era5_land_wet=ds['total_list_era5_land'].values.tolist()
total_era5_ocean_monthly_wet=ds['total_era5_ocean_monthly'].values
total_era5_land_monthly_wet=ds['total_era5_land_monthly'].values

ds=xr.open_dataset(dir_data+'precip_datasets_compare_era5_x_6070_test.nc')
total_list_era5_ocean_98=ds['total_list_era5_ocean'].values.tolist()
total_list_era5_land_98=ds['total_list_era5_land'].values.tolist()
total_era5_ocean_monthly_98=ds['total_era5_ocean_monthly'].values
total_era5_land_monthly_98=ds['total_era5_land_monthly'].values

ds=xr.open_dataset(dir_data+'precip_datasets_compare_era5_r95p_6070_test.nc')
total_list_era5_ocean_95=ds['total_list_era5_ocean'].values.tolist()
total_list_era5_land_95=ds['total_list_era5_land'].values.tolist()
total_era5_ocean_monthly_95=ds['total_era5_ocean_monthly'].values
total_era5_land_monthly_95=ds['total_era5_land_monthly'].values

ds=xr.open_dataset(dir_data+'precip_datasets_compare_era5_r99p_6070_test.nc')
total_list_era5_ocean_99=ds['total_list_era5_ocean'].values.tolist()
total_list_era5_land_99=ds['total_list_era5_land'].values.tolist()
total_era5_ocean_monthly_99=ds['total_era5_ocean_monthly'].values
total_era5_land_monthly_99=ds['total_era5_land_monthly'].values

# %%
ds=xr.open_dataset(dir_data+'precip_datasets_compare_regen_wet_6070_test.nc')
total_list_regen_land_wet=ds['total_list_regen_land'].values.tolist()
total_regen_land_monthly_wet=ds['total_regen_land_monthly'].values

ds=xr.open_dataset(dir_data+'precip_datasets_compare_regen_x_6070_test.nc')
total_list_regen_land_98=ds['total_list_regen_land'].values.tolist()
total_regen_land_monthly_98=ds['total_regen_land_monthly'].values

ds=xr.open_dataset(dir_data+'precip_datasets_compare_regen_r95p_6070_test.nc')
total_list_regen_land_95=ds['total_list_regen_land'].values.tolist()
total_regen_land_monthly_95=ds['total_regen_land_monthly'].values

ds=xr.open_dataset(dir_data+'precip_datasets_compare_regen_r99p_6070_test.nc')
total_list_regen_land_99=ds['total_list_regen_land'].values.tolist()
total_regen_land_monthly_99=ds['total_regen_land_monthly'].values

# %%
yrs=np.arange(1983,2023,1)
fig=plt.figure(figsize=(12,12))
ax=plt.subplot(1,1,1)

test=[x for x in total_list_persiann_land_wet]
test1=[x for x in test if x>=0]
mean=float(sum(test1))/float(len(test1))

zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0]
select_values=[x[1] for x in zipped_years if x[1]>=0]
r=st.linregress(select_years,select_values)
change=r[0]*len(yrs)
label_1='Wet (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

test=[x/mean for x in test]
ax.plot(yrs,test,linewidth=8,color='c',label=label_1,zorder=100)

ax.plot(1983,test[0],marker='o',color='c',markersize=10)
ax.plot(1985,test[2],marker='o',color='c',markersize=10)


######
test=[x for x in total_list_persiann_land_98]
test1=[x for x in test if x>=0]
mean=float(sum(test1))/float(len(test1))

zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0]
select_values=[x[1] for x in zipped_years if x[1]>=0]
r=st.linregress(select_years,select_values)
change=r[0]*len(yrs)
label_2='98$\mathregular{p_{all}}$ (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

test=[x/mean for x in test]
ax.plot(yrs,test,linewidth=8,color='dodgerblue',label=label_2,zorder=99)

ax.plot(1983,test[0],marker='o',color='dodgerblue',markersize=10)
ax.plot(1985,test[2],marker='o',color='dodgerblue',markersize=10)

#####
test=[x for x in total_list_persiann_land_95]
test1=[x for x in test if x>=0]
mean=float(sum(test1))/float(len(test1))

zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0]
select_values=[x[1] for x in zipped_years if x[1]>=0]
r=st.linregress(select_years,select_values)
change=r[0]*len(yrs)
label_3='95p (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

test=[x/mean for x in test]
ax.plot(yrs,test,linewidth=8,color='b',label=label_3,zorder=98)

ax.plot(1983,test[0],marker='o',color='b',markersize=10)
ax.plot(1985,test[2],marker='o',color='b',markersize=10)

######
test=[x for x in total_list_persiann_land_99]
test1=[x for x in test if x>=0]
mean=float(sum(test1))/float(len(test1))

zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0]
select_values=[x[1] for x in zipped_years if x[1]>=0]
r=st.linregress(select_years,select_values)
change=r[0]*len(yrs)
label_4='99p (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

test=[x/mean for x in test]
ax.plot(yrs,test,linewidth=8,color='m',label=label_4)

ax.plot(1983,test[0],marker='o',color='m',markersize=10)
ax.plot(1985,test[2],marker='o',color='m',markersize=10)

ax.tick_params(labelsize=28)
ax.set_xlabel('Year',fontsize=30)
ax.set_ylabel('Normalized value',fontsize=30)
ax.set_title(r'$\bf{PERSIANN-CDR}$',fontsize=42,pad=5)
ax.grid(True,linewidth=1.5)

ax.set_xlim(1939.3,2023.7)
ax.set_ylim(0.5,2)
plt.xticks([1960,1980,2000,2020])

plt.legend(loc='upper center',fontsize=25,ncol=1)
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(1.5)

plt.show()

# %%
fig.savefig(dir_data+'consensus_panel_1.png')

# %%
yrs=np.arange(1940,2023,1)
fig=plt.figure(figsize=(12,12))
ax=plt.subplot(1,1,1)

test=[x for x in total_list_era5_land_wet]
test1=[x for x in test if x>=0]

zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0 and 1980<=x[0]<=2022]
select_values=[x[1] for x in zipped_years if x[1]>=0 and 1980<=x[0]<=2022]
mean=float(sum(select_values))/float(len(select_values))
r=st.linregress(select_years,select_values)
change=r[0]*len(yrs)
label_1='Wet (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

test=[x/mean for x in test]
ax.plot(yrs,test,linewidth=8,color='c',label=label_1,zorder=100)


######
test=[x for x in total_list_era5_land_98]
test1=[x for x in test if x>=0]

zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0 and 1980<=x[0]<=2022]
select_values=[x[1] for x in zipped_years if x[1]>=0 and 1980<=x[0]<=2022]
mean=float(sum(select_values))/float(len(select_values))
r=st.linregress(select_years,select_values)
change=r[0]*len(yrs)
label_2='98$\mathregular{p_{all}}$ (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

test=[x/mean for x in test]
ax.plot(yrs,test,linewidth=8,color='dodgerblue',label=label_2,zorder=99)


#####
test=[x for x in total_list_era5_land_95]
test1=[x for x in test if x>=0]

zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0 and 1980<=x[0]<=2022]
select_values=[x[1] for x in zipped_years if x[1]>=0 and 1980<=x[0]<=2022]
mean=float(sum(select_values))/float(len(select_values))
r=st.linregress(select_years,select_values)
change=r[0]*len(yrs)
label_3='95p (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

test=[x/mean for x in test]
ax.plot(yrs,test,linewidth=8,color='b',label=label_3,zorder=98)


######
test=[x for x in total_list_era5_land_99]
test1=[x for x in test if x>=0]

zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0 and 1980<=x[0]<=2022]
select_values=[x[1] for x in zipped_years if x[1]>=0 and 1980<=x[0]<=2022]
mean=float(sum(select_values))/float(len(select_values))
r=st.linregress(select_years,select_values)
change=r[0]*len(yrs)
label_4='99p (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

test=[x/mean for x in test]
ax.plot(yrs,test,linewidth=8,color='m',label=label_4)

ax.tick_params(labelsize=28)
ax.set_xlabel('Year',fontsize=30)
ax.set_ylabel('Normalized value',fontsize=30)
ax.set_title(r'$\bf{ERA5}$',fontsize=42,pad=5)
ax.grid(True,linewidth=1.5)

ax.set_xlim(1939.3,2023.7)
ax.set_ylim(0.5,2)
plt.xticks([1960,1980,2000,2020])

plt.legend(loc='upper center',fontsize=25,ncol=1)
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(1.5)

plt.show()

# %%
fig.savefig(dir_data+'consensus_panel_2.png')

# %%
yrs=np.arange(1980,2023,1)
fig=plt.figure(figsize=(12,12))
ax=plt.subplot(1,1,1)

test=[x for x in total_list_merra2_land_wet]
test1=[x for x in test if x>=0]
mean=float(sum(test1))/float(len(test1))

zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0]
select_values=[x[1] for x in zipped_years if x[1]>=0]
r=st.linregress(select_years,select_values)
change=r[0]*len(yrs)
label_1='Wet (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

test=[x/mean for x in test]
ax.plot(yrs,test,linewidth=8,color='c',label=label_1,zorder=100)


######
test=[x for x in total_list_merra2_land_98]
test1=[x for x in test if x>=0]
mean=float(sum(test1))/float(len(test1))

zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0]
select_values=[x[1] for x in zipped_years if x[1]>=0]
r=st.linregress(select_years,select_values)
change=r[0]*len(yrs)
label_2='98$\mathregular{p_{all}}$ (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

test=[x/mean for x in test]
ax.plot(yrs,test,linewidth=8,color='dodgerblue',label=label_2,zorder=99)


#####
test=[x for x in total_list_merra2_land_95]
test1=[x for x in test if x>=0]
mean=float(sum(test1))/float(len(test1))

zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0]
select_values=[x[1] for x in zipped_years if x[1]>=0]
r=st.linregress(select_years,select_values)
change=r[0]*len(yrs)
label_3='95p (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

test=[x/mean for x in test]
ax.plot(yrs,test,linewidth=8,color='b',label=label_3,zorder=98)


######
test=[x for x in total_list_merra2_land_99]
test1=[x for x in test if x>=0]
mean=float(sum(test1))/float(len(test1))

zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0]
select_values=[x[1] for x in zipped_years if x[1]>=0]
r=st.linregress(select_years,select_values)
change=r[0]*len(yrs)
label_4='99p (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

test=[x/mean for x in test]
ax.plot(yrs,test,linewidth=8,color='m',label=label_4)

ax.tick_params(labelsize=28)
ax.set_xlabel('Year',fontsize=30)
ax.set_ylabel('Normalized value',fontsize=30)
ax.set_title(r'$\bf{MERRA-2}$',fontsize=42,pad=5)
ax.grid(True,linewidth=1.5)

ax.set_xlim(1939.3,2023.7)
ax.set_ylim(0.5,2)
plt.xticks([1960,1980,2000,2020])

plt.legend(loc='upper center',fontsize=25,ncol=1)
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(1.5)

plt.show()

# %%
fig.savefig(dir_data+'consensus_panel_3.png')

# %%
yrs=np.arange(1958,2023,1)
fig=plt.figure(figsize=(12,12))
ax=plt.subplot(1,1,1)

test=[x for x in total_list_jra55_land_wet]
test1=[x for x in test if x>=0]

zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0 and 1980<=x[0]<=2022]
select_values=[x[1] for x in zipped_years if x[1]>=0 and 1980<=x[0]<=2022]
mean=float(sum(select_values))/float(len(select_values))
r=st.linregress(select_years,select_values)
change=r[0]*len(yrs)
label_1='Wet (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

test=[x/mean for x in test]
ax.plot(yrs,test,linewidth=8,color='c',label=label_1,zorder=100)


######
test=[x for x in total_list_jra55_land_98]
test1=[x for x in test if x>=0]

zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0 and 1980<=x[0]<=2022]
select_values=[x[1] for x in zipped_years if x[1]>=0 and 1980<=x[0]<=2022]
mean=float(sum(select_values))/float(len(select_values))
r=st.linregress(select_years,select_values)
change=r[0]*len(yrs)
label_2='98$\mathregular{p_{all}}$ (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

test=[x/mean for x in test]
ax.plot(yrs,test,linewidth=8,color='dodgerblue',label=label_2,zorder=99)


#####
test=[x for x in total_list_jra55_land_95]
test1=[x for x in test if x>=0]

zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0 and 1980<=x[0]<=2022]
select_values=[x[1] for x in zipped_years if x[1]>=0 and 1980<=x[0]<=2022]
mean=float(sum(select_values))/float(len(select_values))
r=st.linregress(select_years,select_values)
change=r[0]*len(yrs)
label_3='95p (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

test=[x/mean for x in test]
ax.plot(yrs,test,linewidth=8,color='b',label=label_3,zorder=98)


######
test=[x for x in total_list_jra55_land_99]
test1=[x for x in test if x>=0]

zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0 and 1980<=x[0]<=2022]
select_values=[x[1] for x in zipped_years if x[1]>=0 and 1980<=x[0]<=2022]
mean=float(sum(select_values))/float(len(select_values))
r=st.linregress(select_years,select_values)
change=r[0]*len(yrs)
label_4='99p (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

test=[x/mean for x in test]
ax.plot(yrs,test,linewidth=8,color='m',label=label_4)

ax.tick_params(labelsize=28)
ax.set_xlabel('Year',fontsize=30)
ax.set_ylabel('Normalized value',fontsize=30)
ax.set_title(r'$\bf{JRA-55}$',fontsize=42,pad=5)
ax.grid(True,linewidth=1.5)

ax.set_xlim(1939.3,2023.7)
ax.set_ylim(0.5,2)
plt.xticks([1960,1980,2000,2020])

plt.legend(loc='upper center',fontsize=25,ncol=1)
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(1.5)

plt.show()

# %%
fig.savefig(dir_data+'consensus_panel_4.png')

# %%
yrs=np.arange(1950,2017,1)
fig=plt.figure(figsize=(12,12))
ax=plt.subplot(1,1,1)

test=[x for x in total_list_regen_land_wet]
test1=[x for x in test if x>=0]

zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0 and 1980<=x[0]<=2022]
select_values=[x[1] for x in zipped_years if x[1]>=0 and 1980<=x[0]<=2022]
mean=float(sum(select_values))/float(len(select_values))
r=st.linregress(select_years,select_values)
change=r[0]*len(yrs)
label_1='Wet (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

test=[x/mean for x in test]
ax.plot(yrs,test,linewidth=8,color='c',label=label_1,zorder=100)


######
test=[x for x in total_list_regen_land_98]
test1=[x for x in test if x>=0]

zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0 and 1980<=x[0]<=2022]
select_values=[x[1] for x in zipped_years if x[1]>=0 and 1980<=x[0]<=2022]
mean=float(sum(select_values))/float(len(select_values))
r=st.linregress(select_years,select_values)
change=r[0]*len(yrs)
label_2='98$\mathregular{p_{all}}$ (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

test=[x/mean for x in test]
ax.plot(yrs,test,linewidth=8,color='dodgerblue',label=label_2,zorder=99)


#####
test=[x for x in total_list_regen_land_95]
test1=[x for x in test if x>=0]

zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0 and 1980<=x[0]<=2022]
select_values=[x[1] for x in zipped_years if x[1]>=0 and 1980<=x[0]<=2022]
mean=float(sum(select_values))/float(len(select_values))
r=st.linregress(select_years,select_values)
change=r[0]*len(yrs)
label_3='95p (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

test=[x/mean for x in test]
ax.plot(yrs,test,linewidth=8,color='b',label=label_3,zorder=98)


######
test=[x for x in total_list_regen_land_99]
test1=[x for x in test if x>=0]

zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0 and 1980<=x[0]<=2022]
select_values=[x[1] for x in zipped_years if x[1]>=0 and 1980<=x[0]<=2022]
mean=float(sum(select_values))/float(len(select_values))
r=st.linregress(select_years,select_values)
change=r[0]*len(yrs)
label_4='99p (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

test=[x/mean for x in test]
ax.plot(yrs,test,linewidth=8,color='m',label=label_4)

ax.tick_params(labelsize=28)
ax.set_xlabel('Year',fontsize=30)
ax.set_ylabel('Normalized value',fontsize=30)
ax.set_title(r'$\bf{REGEN}$'+' '+r'$\bf{HQ}$',fontsize=42,pad=5)
#ax.set_title(r'$\bf{REGEN}$',fontsize=42,pad=5)
ax.grid(True,linewidth=1.5)

ax.set_xlim(1939.3,2023.7)
ax.set_ylim(0.5,2)
plt.xticks([1960,1980,2000,2020])

plt.legend(loc='upper center',fontsize=25,ncol=1)
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(1.5)

plt.show()

# %%
fig.savefig(dir_data+'consensus_panel_5.png')

# %%
yrs=np.arange(1982,2021,1)
fig=plt.figure(figsize=(12,12))
ax=plt.subplot(1,1,1)

test=[x for x in total_list_gpcc_land_wet]
test1=[x for x in test if x>=0]
mean=float(sum(test1))/float(len(test1))

zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0]
select_values=[x[1] for x in zipped_years if x[1]>=0]
r=st.linregress(select_years,select_values)
change=r[0]*len(yrs)
label_1='Wet (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

test=[x/mean for x in test]
ax.plot(yrs,test,linewidth=8,color='c',label=label_1,zorder=100)


######
test=[x for x in total_list_gpcc_land_98]
test1=[x for x in test if x>=0]
mean=float(sum(test1))/float(len(test1))

zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0]
select_values=[x[1] for x in zipped_years if x[1]>=0]
r=st.linregress(select_years,select_values)
change=r[0]*len(yrs)
label_2='98$\mathregular{p_{all}}$ (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

test=[x/mean for x in test]
ax.plot(yrs,test,linewidth=8,color='dodgerblue',label=label_2,zorder=99)


#####
test=[x for x in total_list_gpcc_land_95]
test1=[x for x in test if x>=0]
mean=float(sum(test1))/float(len(test1))

zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0]
select_values=[x[1] for x in zipped_years if x[1]>=0]
r=st.linregress(select_years,select_values)
change=r[0]*len(yrs)
label_3='95p (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

test=[x/mean for x in test]
ax.plot(yrs,test,linewidth=8,color='b',label=label_3,zorder=98)


######
test=[x for x in total_list_gpcc_land_99]
test1=[x for x in test if x>=0]
mean=float(sum(test1))/float(len(test1))

zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0]
select_values=[x[1] for x in zipped_years if x[1]>=0]
r=st.linregress(select_years,select_values)
change=r[0]*len(yrs)
label_4='99p (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

test=[x/mean for x in test]
ax.plot(yrs,test,linewidth=8,color='m',label=label_4)

ax.tick_params(labelsize=28)
ax.set_xlabel('Year',fontsize=30)
ax.set_ylabel('Normalized value',fontsize=30)
ax.set_title(r'$\bf{GPCC}$'+' '+r'$\bf{V2022}$',fontsize=42,pad=5)
ax.grid(True,linewidth=1.5)

ax.set_xlim(1939.3,2023.7)
ax.set_ylim(0.5,2)
plt.xticks([1960,1980,2000,2020])

plt.legend(loc='upper center',fontsize=25,ncol=1)
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(1.5)

plt.show()

# %%
fig.savefig(dir_data+'consensus_panel_6.png')

# %%
yrs=np.arange(1997,2023,1)
fig=plt.figure(figsize=(12,12))
ax=plt.subplot(1,1,1)

test=[x for x in total_list_gpcp_land_wet]
test1=[x for x in test if x>=0]
mean=float(sum(test1))/float(len(test1))

zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0]
select_values=[x[1] for x in zipped_years if x[1]>=0]
r=st.linregress(select_years,select_values)
change=r[0]*len(yrs)
label_1='Wet (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

test=[x/mean for x in test]
ax.plot(yrs,test,linewidth=8,color='c',label=label_1,zorder=100)


######
test=[x for x in total_list_gpcp_land_98]
test1=[x for x in test if x>=0]
mean=float(sum(test1))/float(len(test1))

zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0]
select_values=[x[1] for x in zipped_years if x[1]>=0]
r=st.linregress(select_years,select_values)
change=r[0]*len(yrs)
label_2='98$\mathregular{p_{all}}$ (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

test=[x/mean for x in test]
ax.plot(yrs,test,linewidth=8,color='dodgerblue',label=label_2,zorder=99)


#####
test=[x for x in total_list_gpcp_land_95]
test1=[x for x in test if x>=0]
mean=float(sum(test1))/float(len(test1))

zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0]
select_values=[x[1] for x in zipped_years if x[1]>=0]
r=st.linregress(select_years,select_values)
change=r[0]*len(yrs)
label_3='95p (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

test=[x/mean for x in test]
ax.plot(yrs,test,linewidth=8,color='b',label=label_3,zorder=98)


######
test=[x for x in total_list_gpcp_land_99]
test1=[x for x in test if x>=0]
mean=float(sum(test1))/float(len(test1))

zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0]
select_values=[x[1] for x in zipped_years if x[1]>=0]
r=st.linregress(select_years,select_values)
change=r[0]*len(yrs)
label_4='99p (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

test=[x/mean for x in test]
ax.plot(yrs,test,linewidth=8,color='m',label=label_4)

ax.tick_params(labelsize=28)
ax.set_xlabel('Year',fontsize=30)
ax.set_ylabel('Normalized value',fontsize=30)
ax.set_title(r'$\bf{GPCP}$'+' '+r'$\bf{v01r03}$',fontsize=42,pad=5)
ax.grid(True,linewidth=1.5)

ax.set_xlim(1939.3,2023.7)
ax.set_ylim(0.5,2)
plt.xticks([1960,1980,2000,2020])

plt.legend(loc='upper center',fontsize=25,ncol=1)
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(1.5)

plt.show()

# %%
fig.savefig(dir_data+'consensus_panel_7.png')

# %%
yrs=np.arange(2001,2021,1)
fig=plt.figure(figsize=(12,12))
ax=plt.subplot(1,1,1)

test=[x for x in total_list_gpcp3_land_wet]
test1=[x for x in test if x>=0]
mean=float(sum(test1))/float(len(test1))

zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0]
select_values=[x[1] for x in zipped_years if x[1]>=0]
r=st.linregress(select_years,select_values)
change=r[0]*len(yrs)
label_1='Wet (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

test=[x/mean for x in test]
ax.plot(yrs,test,linewidth=8,color='c',label=label_1,zorder=100)


######
test=[x for x in total_list_gpcp3_land_98]
test1=[x for x in test if x>=0]
mean=float(sum(test1))/float(len(test1))

zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0]
select_values=[x[1] for x in zipped_years if x[1]>=0]
r=st.linregress(select_years,select_values)
change=r[0]*len(yrs)
label_2='98$\mathregular{p_{all}}$ (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

test=[x/mean for x in test]
ax.plot(yrs,test,linewidth=8,color='dodgerblue',label=label_2,zorder=99)


#####
test=[x for x in total_list_gpcp3_land_95]
test1=[x for x in test if x>=0]
mean=float(sum(test1))/float(len(test1))

zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0]
select_values=[x[1] for x in zipped_years if x[1]>=0]
r=st.linregress(select_years,select_values)
change=r[0]*len(yrs)
label_3='95p (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

test=[x/mean for x in test]
ax.plot(yrs,test,linewidth=8,color='b',label=label_3,zorder=98)


######
test=[x for x in total_list_gpcp3_land_99]
test1=[x for x in test if x>=0]
mean=float(sum(test1))/float(len(test1))

zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0]
select_values=[x[1] for x in zipped_years if x[1]>=0]
r=st.linregress(select_years,select_values)
change=r[0]*len(yrs)
label_4='99p (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

test=[x/mean for x in test]
ax.plot(yrs,test,linewidth=8,color='m',label=label_4)

ax.tick_params(labelsize=28)
ax.set_xlabel('Year',fontsize=30)
ax.set_ylabel('Normalized value',fontsize=30)
ax.set_title(r'$\bf{GPCP}$'+' '+r'$\bf{V3.2}$',fontsize=42,pad=5)
ax.grid(True,linewidth=1.5)

ax.set_xlim(1939.3,2023.7)
ax.set_ylim(0.5,2)
plt.xticks([1960,1980,2000,2020])

plt.legend(loc='upper center',fontsize=25,ncol=1)
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(1.5)

plt.show()

# %%
fig.savefig(dir_data+'consensus_panel_8.png')

# %%
yrs=np.arange(1979,2021,1)
fig=plt.figure(figsize=(12,12))
ax=plt.subplot(1,1,1)

test=[x for x in total_list_mswep_past_land_wet]
test1=[x for x in test if x>=0]

zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0 and 1980<=x[0]<=2022]
select_values=[x[1] for x in zipped_years if x[1]>=0 and 1980<=x[0]<=2022]
mean=float(sum(select_values))/float(len(select_values))
r=st.linregress(select_years,select_values)
change=r[0]*len(yrs)
label_1='Wet (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

test=[x/mean for x in test]
ax.plot(yrs,test,linewidth=8,color='c',label=label_1,zorder=100)


######
test=[x for x in total_list_mswep_past_land_98]
test1=[x for x in test if x>=0]

zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0 and 1980<=x[0]<=2022]
select_values=[x[1] for x in zipped_years if x[1]>=0 and 1980<=x[0]<=2022]
mean=float(sum(select_values))/float(len(select_values))
r=st.linregress(select_years,select_values)
change=r[0]*len(yrs)
label_2='98$\mathregular{p_{all}}$ (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

test=[x/mean for x in test]
ax.plot(yrs,test,linewidth=8,color='dodgerblue',label=label_2,zorder=99)


#####
test=[x for x in total_list_mswep_past_land_95]
test1=[x for x in test if x>=0]

zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0 and 1980<=x[0]<=2022]
select_values=[x[1] for x in zipped_years if x[1]>=0 and 1980<=x[0]<=2022]
mean=float(sum(select_values))/float(len(select_values))
r=st.linregress(select_years,select_values)
change=r[0]*len(yrs)
label_3='95p (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

test=[x/mean for x in test]
ax.plot(yrs,test,linewidth=8,color='b',label=label_3,zorder=98)


######
test=[x for x in total_list_mswep_past_land_99]
test1=[x for x in test if x>=0]

zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0 and 1980<=x[0]<=2022]
select_values=[x[1] for x in zipped_years if x[1]>=0 and 1980<=x[0]<=2022]
mean=float(sum(select_values))/float(len(select_values))
r=st.linregress(select_years,select_values)
change=r[0]*len(yrs)
label_4='99p (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

test=[x/mean for x in test]
ax.plot(yrs,test,linewidth=8,color='m',label=label_4)

ax.tick_params(labelsize=28)
ax.set_xlabel('Year',fontsize=30)
ax.set_ylabel('Normalized value',fontsize=30)
ax.set_title(r'$\bf{MSWEP}$'+' '+r'$\bf{V2.8}$',fontsize=42,pad=5)
ax.grid(True,linewidth=1.5)

ax.set_xlim(1939.3,2023.7)
ax.set_ylim(0.5,2)
plt.xticks([1960,1980,2000,2020])

plt.legend(loc='upper center',fontsize=25,ncol=1)
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(1.5)

plt.show()

# %%
fig.savefig(dir_data+'consensus_panel_9.png')

# %%
yrs=np.arange(1979,2024,1)
fig=plt.figure(figsize=(12,12))
ax=plt.subplot(1,1,1)

test=[x for x in total_list_cpc_land_wet]
test1=[x for x in test if x>=0]

zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0 and 1980<=x[0]<=2022]
select_values=[x[1] for x in zipped_years if x[1]>=0 and 1980<=x[0]<=2022]
mean=float(sum(select_values))/float(len(select_values))
r=st.linregress(select_years,select_values)
change=r[0]*len(yrs)
label_1='Wet (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

test=[x/mean for x in test]
ax.plot(yrs,test,linewidth=8,color='c',label=label_1,zorder=100)


######
test=[x for x in total_list_cpc_land_98]
test1=[x for x in test if x>=0]

zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0 and 1980<=x[0]<=2022]
select_values=[x[1] for x in zipped_years if x[1]>=0 and 1980<=x[0]<=2022]
mean=float(sum(select_values))/float(len(select_values))
r=st.linregress(select_years,select_values)
change=r[0]*len(yrs)
label_2='98$\mathregular{p_{all}}$ (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

test=[x/mean for x in test]
ax.plot(yrs,test,linewidth=8,color='dodgerblue',label=label_2,zorder=99)


#####
test=[x for x in total_list_cpc_land_95]
test1=[x for x in test if x>=0]

zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0 and 1980<=x[0]<=2022]
select_values=[x[1] for x in zipped_years if x[1]>=0 and 1980<=x[0]<=2022]
mean=float(sum(select_values))/float(len(select_values))
r=st.linregress(select_years,select_values)
change=r[0]*len(yrs)
label_3='95p (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

test=[x/mean for x in test]
ax.plot(yrs,test,linewidth=8,color='b',label=label_3,zorder=98)


######
test=[x for x in total_list_cpc_land_99]
test1=[x for x in test if x>=0]

zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0 and 1980<=x[0]<=2022]
select_values=[x[1] for x in zipped_years if x[1]>=0 and 1980<=x[0]<=2022]
mean=float(sum(select_values))/float(len(select_values))
r=st.linregress(select_years,select_values)
change=r[0]*len(yrs)
label_4='99p (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

test=[x/mean for x in test]
ax.plot(yrs,test,linewidth=8,color='m',label=label_4)

ax.tick_params(labelsize=28)
ax.set_xlabel('Year',fontsize=30)
ax.set_ylabel('Normalized value',fontsize=30)
ax.set_title(r'$\bf{CPC}$'+' '+r'$\bf{Unified}$',fontsize=42,pad=5)
ax.grid(True,linewidth=1.5)

ax.set_xlim(1939.3,2023.7)
ax.set_ylim(0.5,2)
plt.xticks([1960,1980,2000,2020])

plt.legend(loc='upper center',fontsize=25,ncol=1)
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(1.5)

plt.show()

# %%
fig.savefig(dir_data+'consensus_panel_10.png')

# %%
yrs=np.arange(2001,2023,1)
fig=plt.figure(figsize=(12,12))
ax=plt.subplot(1,1,1)

test=[x for x in total_list_imerg_land_wet]
test1=[x for x in test if x>=0]
mean=float(sum(test1))/float(len(test1))

zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0]
select_values=[x[1] for x in zipped_years if x[1]>=0]
r=st.linregress(select_years,select_values)
change=r[0]*len(yrs)
label_1='Wet (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

test=[x/mean for x in test]
ax.plot(yrs,test,linewidth=8,color='c',label=label_1,zorder=100)


######
test=[x for x in total_list_imerg_land_98]
test1=[x for x in test if x>=0]
mean=float(sum(test1))/float(len(test1))

zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0]
select_values=[x[1] for x in zipped_years if x[1]>=0]
r=st.linregress(select_years,select_values)
change=r[0]*len(yrs)
label_2='98$\mathregular{p_{all}}$ (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

test=[x/mean for x in test]
ax.plot(yrs,test,linewidth=8,color='dodgerblue',label=label_2,zorder=99)


#####
test=[x for x in total_list_imerg_land_95]
test1=[x for x in test if x>=0]
mean=float(sum(test1))/float(len(test1))

zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0]
select_values=[x[1] for x in zipped_years if x[1]>=0]
r=st.linregress(select_years,select_values)
change=r[0]*len(yrs)
label_3='95p (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

test=[x/mean for x in test]
ax.plot(yrs,test,linewidth=8,color='b',label=label_3,zorder=98)


######
test=[x for x in total_list_imerg_land_99]
test1=[x for x in test if x>=0]
mean=float(sum(test1))/float(len(test1))

zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0]
select_values=[x[1] for x in zipped_years if x[1]>=0]
r=st.linregress(select_years,select_values)
change=r[0]*len(yrs)
label_4='99p (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

test=[x/mean for x in test]
ax.plot(yrs,test,linewidth=8,color='m',label=label_4)

ax.tick_params(labelsize=28)
ax.set_xlabel('Year',fontsize=30)
ax.set_ylabel('Normalized value',fontsize=30)
ax.set_title(r'$\bf{IMERG}$'+' '+r'$\bf{V07a}$',fontsize=42,pad=5)
ax.grid(True,linewidth=1.5)

ax.set_xlim(1939.3,2023.7)
ax.set_ylim(0.5,2)
plt.xticks([1960,1980,2000,2020])

plt.legend(loc='upper center',fontsize=25,ncol=1)
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(1.5)

plt.show()

# %%
fig.savefig(dir_data+'consensus_panel_11.png')

# %%
ds.close()
ds=xr.open_dataset(dir_data+'hadex3_lines_r99p.nc')
starting_01_99=ds['starting_01'].values.tolist()
starting_40_99=ds['starting_40'].values.tolist()
starting_50_99=ds['starting_50'].values.tolist()
starting_79_99=ds['starting_79'].values.tolist()

ds=xr.open_dataset(dir_data+'hadex3_lines_r95p.nc')
starting_01_95=ds['starting_01'].values.tolist()
starting_40_95=ds['starting_40'].values.tolist()
starting_50_95=ds['starting_50'].values.tolist()
starting_79_95=ds['starting_79'].values.tolist()

ds=xr.open_dataset(dir_data+'hadex3_lines_total.nc')
starting_01_total=ds['starting_01'].values.tolist()
starting_40_total=ds['starting_40'].values.tolist()
starting_50_total=ds['starting_50'].values.tolist()
starting_79_total=ds['starting_79'].values.tolist()

# %%
yrs=np.arange(1940,2019,1)
fig=plt.figure(figsize=(12,12))
ax=plt.subplot(1,1,1)

test=[x for x in starting_40_total]
test1=[x for x in test if x>=0]
mean=float(sum(test1))/float(len(test1))

zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0]
select_values=[x[1] for x in zipped_years if x[1]>=0]
r=st.linregress(select_years,select_values)
change=r[0]*len(yrs)
label_1='Total (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

test=[x/mean for x in test]
ax.plot(yrs,test,linewidth=8,color='c',label=label_1,zorder=100)

#####
test=[x for x in starting_40_95]
test1=[x for x in test if x>=0]
mean=float(sum(test1))/float(len(test1))

zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0]
select_values=[x[1] for x in zipped_years if x[1]>=0]
r=st.linregress(select_years,select_values)
change=r[0]*len(yrs)
label_3='95p (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

test=[x/mean for x in test]
ax.plot(yrs,test,linewidth=8,color='b',label=label_3,zorder=99)


######
test=[x for x in starting_40_99]
test1=[x for x in test if x>=0]
mean=float(sum(test1))/float(len(test1))

zipped_years=list(zip(yrs,test))
select_years=[x[0] for x in zipped_years if x[1]>=0]
select_values=[x[1] for x in zipped_years if x[1]>=0]
r=st.linregress(select_years,select_values)
change=r[0]*len(yrs)
label_4='99p (Mean='+str(round(mean,1))+', '+'$\Delta$='+str(round(change,2))+', p='+str(round(r[3],3))+')'

test=[x/mean for x in test]
ax.plot(yrs,test,linewidth=8,color='m',label=label_4)

ax.tick_params(labelsize=28)
ax.set_xlabel('Year',fontsize=30)
ax.set_ylabel('Normalized value',fontsize=30)
ax.set_title(r'$\bf{HadEX3}$'+' '+r'$\bf{1940}$',fontsize=42,pad=5)
ax.grid(True,linewidth=1.5)

ax.set_xlim(1939.3,2023.7)
ax.set_ylim(0.5,2)
plt.xticks([1960,1980,2000,2020])

plt.legend(loc='upper center',fontsize=25,ncol=1)
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(1.5)

plt.show()

# %%
fig.savefig(dir_data+'consensus_panel_12.png')
